# %% [markdown]
# # New York State Industry
#
# Cecilia Pershyn
# Assignment 2
# Data Configuration

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
NYS_employment_2017_1 = pd.read_csv('NYS_Employment_2017_1.csv')
NYS_employment_2017_2 = pd.read_csv('NYS_Employment_2017_2.csv')
NYS_employment_2017_3 = pd.read_csv('NYS_Employment_2017_3.csv')
NYS_employment_2017_4 = pd.read_csv('NYS_Employment_2017_4.csv')

# %%
NYS_employment_2017_1.head()
# Out:
#    area_fips  own_code industry_code  agglvl_code  size_code  year  qtr  \
# 0      36000         0            10           50          0  2017    1
# 1      36000         1            10           51          0  2017    1
# 2      36000         1           101           52          0  2017    1
# 3      36000         1          1013           53          0  2017    1
# 4      36000         1           102           52          0  2017    1
#
#   disclosure_code  qtrly_estabs  month1_emplvl            ...              \
# 0             NaN        629058        9059983            ...
# 1             NaN          2649         117175            ...
# 2             NaN             2              4            ...
# 3             NaN             2              4            ...
# 4             NaN          2647         117171            ...
#
#    oty_month3_emplvl_chg  oty_month3_emplvl_pct_chg  \
# 0                 112447                        1.2
# ...

# %% [markdown]
# Create a column in the dataframe that summarizes the employment level for all 3 months in the quarter.  The result is the total employment level for industries in the quarter.

# %%
NYS_employment_2017_1['quarter1_emplvl'] = NYS_employment_2017_1['month1_emplvl'] + NYS_employment_2017_1['month2_emplvl'] + NYS_employment_2017_1['month3_emplvl']
NYS_employment_2017_1.head()
# Out:
#    area_fips  own_code industry_code  agglvl_code  size_code  year  qtr  \
# 0      36000         0            10           50          0  2017    1
# 1      36000         1            10           51          0  2017    1
# 2      36000         1           101           52          0  2017    1
# 3      36000         1          1013           53          0  2017    1
# 4      36000         1           102           52          0  2017    1
#
#   disclosure_code  qtrly_estabs  month1_emplvl       ...         \
# 0             NaN        629058        9059983       ...
# 1             NaN          2649         117175       ...
# 2             NaN             2              4       ...
# 3             NaN             2              4       ...
# 4             NaN          2647         117171       ...
#
#    oty_month3_emplvl_pct_chg  oty_total_qtrly_wages_chg  \
# 0                        1.2                13070954019
# 1                        1.1                   49815766
# ...

# %% [markdown]
# Create a new dataframe using only the columns that are relevant to study.  In this case I chose to look at industry, quarterly contributions, total quarterly wages, and total quarterly employment level.

# %%
NYS_employment_2017_1 = NYS_employment_2017_1[['year','qtr','industry_code','qtrly_contributions','total_qtrly_wages','quarter1_emplvl']]
NYS_employment_2017_1.head()
# Out:
#    year  qtr industry_code  qtrly_contributions  total_qtrly_wages  \
# 0  2017    1            10           1529251900       182980473877
# 1  2017    1            10                    0         2222130245
# 2  2017    1           101                    0             142815
# 3  2017    1          1013                    0             142815
# 4  2017    1           102                    0         2221987430
#
#    quarter1_emplvl
# 0         27325310
# 1           351238
# 2               13
# 3               13
# 4           351225

# %% [markdown]
# Rename the columns to indicate they represent values for quarter 1.

# %%
NYS_industry_2017_1 = NYS_employment_2017_1.rename(columns={'qtrly_contributions':'qtr1_contributions','total_qtrly_wages':'qtr1_wages'})
NYS_industry_2017_1.head()
# Out:
#    year  qtr industry_code  qtr1_contributions    qtr1_wages  quarter1_emplvl
# 0  2017    1            10          1529251900  182980473877         27325310
# 1  2017    1            10                   0    2222130245           351238
# 2  2017    1           101                   0        142815               13
# 3  2017    1          1013                   0        142815               13
# 4  2017    1           102                   0    2221987430           351225

# %% [markdown]
# Repeat the two steps above for quarters 2-4 of 2017.

# %%
NYS_employment_2017_2['quarter2_emplvl'] = NYS_employment_2017_2['month1_emplvl'] + NYS_employment_2017_2['month2_emplvl'] + NYS_employment_2017_2['month3_emplvl']
NYS_employment_2017_2.head()
# Out:
#    area_fips  own_code industry_code  agglvl_code  size_code  year  qtr  \
# 0      36000         0            10           50          0  2017    2
# 1      36000         1            10           51          0  2017    2
# 2      36000         1           101           52          0  2017    2
# 3      36000         1          1013           53          0  2017    2
# 4      36000         1           102           52          0  2017    2
#
#   disclosure_code  qtrly_estabs  month1_emplvl       ...         \
# 0             NaN        636021        9223298       ...
# 1             NaN          2641         116595       ...
# 2             NaN             2              4       ...
# 3             NaN             2              4       ...
# 4             NaN          2639         116591       ...
#
#    oty_month3_emplvl_pct_chg  oty_total_qtrly_wages_chg  \
# 0                        1.6                 5695361995
# 1                       -0.1                  220070846
# ...

# %%
NYS_employment_2017_2 = NYS_employment_2017_2[['year','qtr','industry_code','qtrly_contributions','total_qtrly_wages','quarter2_emplvl']]
NYS_industry_2017_2 = NYS_employment_2017_2.rename(columns={'qtrly_contributions':'qtr2_contributions','total_qtrly_wages':'qtr2_wages'})
NYS_industry_2017_2.head()
# Out:
#    year  qtr industry_code  qtr2_contributions    qtr2_wages  quarter2_emplvl
# 0  2017    2            10           494482035  150417320920         27964380
# 1  2017    2            10                   0    2217175239           349367
# 2  2017    2           101                   0         97634               14
# 3  2017    2          1013                   0         97634               14
# 4  2017    2           102                   0    2217077605           349353

# %%
NYS_employment_2017_3['quarter3_emplvl'] = NYS_employment_2017_3['month1_emplvl'] + NYS_employment_2017_3['month2_emplvl'] + NYS_employment_2017_3['month3_emplvl']
NYS_employment_2017_3 = NYS_employment_2017_3[['year','qtr','industry_code','qtrly_contributions','total_qtrly_wages','quarter3_emplvl']]
NYS_industry_2017_3 = NYS_employment_2017_3.rename(columns={'qtrly_contributions':'qtr3_contributions','total_qtrly_wages':'qtr3_wages'})
NYS_industry_2017_3.head()
# Out:
#    year  qtr industry_code  qtr3_contributions    qtr3_wages  quarter3_emplvl
# 0  2017    4            10           267758192  175843272174         28347532
# 1  2017    4            10                   0    2315826762           347186
# 2  2017    4           101                   0         91119               10
# 3  2017    4          1013                   0         91119               10
# 4  2017    4           102                   0    2315735643           347176

# %%
NYS_employment_2017_4['quarter4_emplvl'] = NYS_employment_2017_4['month1_emplvl'] + NYS_employment_2017_4['month2_emplvl'] + NYS_employment_2017_4['month3_emplvl']
NYS_employment_2017_4 = NYS_employment_2017_4[['year','qtr','industry_code','qtrly_contributions','total_qtrly_wages','quarter4_emplvl']]
NYS_industry_2017_4 = NYS_employment_2017_4.rename(columns={'qtrly_contributions':'qtr4_contributions','total_qtrly_wages':'qtr4_wages'})
NYS_industry_2017_4.head()
# Out:
#    year  qtr industry_code  qtr4_contributions    qtr4_wages  quarter4_emplvl
# 0  2017    3            10           337029234  146464293659         27685193
# 1  2017    3            10                   0    2225207312           347135
# 2  2017    3           101                   0        143882               15
# 3  2017    3          1013                   0        143882               15
# 4  2017    3           102                   0    2225063430           347120

# %% [markdown]
# Combine quarter 1 and quarter 2 into one dataframe.  Then add quarter 3, and finally quarter 4.

# %%
NYS_Industry_2017_12 = pd.merge(NYS_industry_2017_1, NYS_industry_2017_2, how='inner', left_on='year', right_on='year')
NYS_Industry_2017_12.head()
# Out:
#    year  qtr_x industry_code_x  qtr1_contributions    qtr1_wages  \
# 0  2017      1              10          1529251900  182980473877
# 1  2017      1              10          1529251900  182980473877
# 2  2017      1              10          1529251900  182980473877
# 3  2017      1              10          1529251900  182980473877
# 4  2017      1              10          1529251900  182980473877
#
#    quarter1_emplvl  qtr_y industry_code_y  qtr2_contributions    qtr2_wages  \
# 0         27325310      2              10           494482035  150417320920
# 1         27325310      2              10                   0    2217175239
# 2         27325310      2             101                   0         97634
# 3         27325310      2            1013                   0         97634
# 4         27325310      2             102                   0    2217077605
#
#    quarter2_emplvl
# 0         27964380
# 1           349367
# 2               14
# 3               14
# ...

# %%
NYS_Industry_2017_12['half1_contributions'] = NYS_Industry_2017_12['qtr1_contributions'] + NYS_Industry_2017_12['qtr2_contributions']
NYS_Industry_2017_12['half1_wages'] = NYS_Industry_2017_12['qtr1_wages'] + NYS_Industry_2017_12['qtr2_wages']
NYS_Industry_2017_12['half1_emplvl'] = NYS_Industry_2017_12['quarter1_emplvl'] + NYS_Industry_2017_12['quarter2_emplvl'] 
NYS_Industry_2017_12.head()
# Out:
#    year  qtr_x industry_code_x  qtr1_contributions    qtr1_wages  \
# 0  2017      1              10          1529251900  182980473877
# 1  2017      1              10          1529251900  182980473877
# 2  2017      1              10          1529251900  182980473877
# 3  2017      1              10          1529251900  182980473877
# 4  2017      1              10          1529251900  182980473877
#
#    quarter1_emplvl  qtr_y industry_code_y  qtr2_contributions    qtr2_wages  \
# 0         27325310      2              10           494482035  150417320920
# 1         27325310      2              10                   0    2217175239
# 2         27325310      2             101                   0         97634
# 3         27325310      2            1013                   0         97634
# 4         27325310      2             102                   0    2217077605
#
#    quarter2_emplvl  half1_contributions   half1_wages  half1_emplvl
# ...

# %%
NYS_employment_2017_6mo = NYS_employment_2017_12[['year', 'industry_code','half1_contributions','half1_wages','half11_emplvl']]
NYS_employment_2017_6mo.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-ac13516c6aad> in <module>()
# ----> 1 NYS_employment_2017_6mo = NYS_employment_2017_12[['year', 'industry_code','half1_contributions','half1_wages','half11_emplvl']]
#       2 NYS_employment_2017_6mo.head()
#
# NameError: name 'NYS_employment_2017_12' is not defined

# %%
NYS_Industry_2017_34 = pd.merge(NYS_industry_2017_3, NYS_industry_2017_4, how='inner', left_on='year', right_on='year')
NYS_Industry_2017_34.head()
# Out:
#    year  qtr_x industry_code_x  qtr3_contributions    qtr3_wages  \
# 0  2017      4              10           267758192  175843272174
# 1  2017      4              10           267758192  175843272174
# 2  2017      4              10           267758192  175843272174
# 3  2017      4              10           267758192  175843272174
# 4  2017      4              10           267758192  175843272174
#
#    quarter3_emplvl  qtr_y industry_code_y  qtr4_contributions    qtr4_wages  \
# 0         28347532      3              10           337029234  146464293659
# 1         28347532      3              10                   0    2225207312
# 2         28347532      3             101                   0        143882
# 3         28347532      3            1013                   0        143882
# 4         28347532      3             102                   0    2225063430
#
#    quarter4_emplvl
# 0         27685193
# 1           347135
# 2               15
# 3               15
# ...

# %%
NYS_Industry_2017_34['half2_contributions'] = NYS_Industry_2017_34['qtr3_contributions'] + NYS_Industry_2017_34['qtr4_contributions']
NYS_Industry_2017_34['half2_wages'] = NYS_Industry_2017_34['qtr3_wages'] + NYS_Industry_2017_34['qtr4_wages']
NYS_Industry_2017_34['half2_emplvl'] = NYS_Industry_2017_34['quarter3_emplvl'] + NYS_Industry_2017_34['quarter4_emplvl'] 
NYS_Industry_2017_34.head()
# Out:
#    year  qtr_x industry_code_x  qtr3_contributions    qtr3_wages  \
# 0  2017      4              10           267758192  175843272174
# 1  2017      4              10           267758192  175843272174
# 2  2017      4              10           267758192  175843272174
# 3  2017      4              10           267758192  175843272174
# 4  2017      4              10           267758192  175843272174
#
#    quarter3_emplvl  qtr_y industry_code_y  qtr4_contributions    qtr4_wages  \
# 0         28347532      3              10           337029234  146464293659
# 1         28347532      3              10                   0    2225207312
# 2         28347532      3             101                   0        143882
# 3         28347532      3            1013                   0        143882
# 4         28347532      3             102                   0    2225063430
#
#    quarter4_emplvl  half2_contributions   half2_wages  half2_emplvl
# ...

# %%
NYS_Industry_2017 = pd.merge(NYS_Industry_2017_12, NYS_Industry_2017_34, how='inner', left_on='year', right_on='year')
NYS_Industry_2017.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-798dea7e4fa1> in <module>()
# ----> 1 NYS_Industry_2017 = pd.merge(NYS_Industry_2017_12, NYS_Industry_2017_34, how='inner', left_on='year', right_on='year')
#       2 NYS_Industry_2017.head()
#
# NameError: name 'NYS_Industry_2017_12' is not defined

# %% [markdown]
# Methods for the rest of the data:
# 1. Combine all informations for the four quarters.  Create new columns summarizing contributions, wages, and employment level for the year.
# 2. Create a new dataframe with only the summarizing columns for the year 2017
# 3. Sort values for employment levels for the year 2017, take the top 5
# 4. Sort values for quarterly wages for the year 2017, take the top 5
# 5. Sort values for contributions for the year 2017, take the top 5
#
#
# See below example of how I would sort the dataframe.  The example below is the first quarter of 2017 sorted 3 ways.

# %% [markdown]
# Top 5 industries in New York State according to employment levels:
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
Employment_2017_1 = NYS_industry_2017_1.sort_values(['quarter1_emplvl'], ascending=[False])
Employment_2017_1[:5]
# Out:
#      year  qtr industry_code  qtr1_contributions    qtr1_wages  \
# 0    2017    1            10          1529251900  182980473877
# 774  2017    1            10          1526714517  161145407747
# 779  2017    1           102          1226934779  147254597140
# 784  2017    1          1025           138298283   22922608383
# 780  2017    1          1021           288913899   19819940633
#
#      quarter1_emplvl
# 0           27325310
# 774         23114400
# 779         20646115
# 784          5490079
# 780          4621009

# %% [markdown]
# Top 5 industries in New York State according to contributions:
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
Contributions_2017_1 = NYS_employment_2017_1.sort_values(['qtrly_contributions'], ascending=[False])
Contributions_2017_1[:5]
# Out:
#      year  qtr industry_code  qtrly_contributions  total_qtrly_wages  \
# 0    2017    1            10           1529251900       182980473877
# 774  2017    1            10           1526714517       161145407747
# 779  2017    1           102           1226934779       147254597140
# 783  2017    1          1024            338655018        31526553941
# 775  2017    1           101            299779738        13890810607
#
#      quarter1_emplvl
# 0           27325310
# 774         23114400
# 779         20646115
# 783          3830616
# 775          2468285

# %% [markdown]
# Top 5 industries in New York State according to total quarterly wages:
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
Wages_2017_1 = NYS_employment_2017_1.sort_values(['total_qtrly_wages'], ascending=[False])
Wages_2017_1[:5]
# Out:
#       year  qtr industry_code  qtrly_contributions  total_qtrly_wages  \
# 0     2017    1            10           1529251900       182980473877
# 774   2017    1            10           1526714517       161145407747
# 779   2017    1           102           1226934779       147254597140
# 782   2017    1          1023            187160049        52970734663
# 2215  2017    1            52            140289974        49029398098
#
#       quarter1_emplvl
# 0            27325310
# 774          23114400
# 779          20646115
# 782           2097920
# 2215          1516522
