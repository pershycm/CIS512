# %% [markdown]
# # Electric Vehicle Data
#
# Objective:  To create a dataframe with "Region" and "Number of Vehicles"
#
# Workflow_1:
# 1. From "vehicle_reg", extract "County" column.
# 2. Use groupby and .agg, count, .sort_values() to create a new column in the dataframe which gives the # of EV registered in each county
# 3. Upload "region" data.  Take only the "region" and "county".  Convert all the "county" values to uppercase.
# 4. Merge "count_county" and "region". Output: a dataframe called "veh_count_reg" with "region" "county" and "number of vehicles" >>This method does not work, the table is riddled with NaN. **Question1: How might I be able to join this dataframe and get rid of NaN values?**
# 5. Create a new dataframe with "region" and "number of vehicles"
# 5. Use groupby and .agg, count, .sort_values() to create a new column in "veh_count_reg" which gives the # of EV registered in each region
#
# *Edit - I make some changes to this workflow as I work through the problem.*
# Workflow_2:
#   1. From "vehicle_reg", extract "County" column.
#   2. Upload "region" data.  Take only the "region" and "county".  Convert all the "county" values to uppercase.
#   3. Merge "County" and "region". Output: ideally, a dataframe called "count_reg" although at the moment, "Albany" occurs numerous times, but "Capital" occurs under region just once, and NaN occurs every time after that.  **Question 2: how do I return a region for every row that county appears?**
#   4. Once I work out how to have a region for every county entry, I can do a groupby in a similar fashion to my method in Workflow_1, but this time with regions.  Output: # of vehicles and regions

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
sns.set(style="darkgrid")

# %%
#upload data
vehicle_reg = pd.read_csv('Vehicle__Snowmobile__and_Boat_Registrations.csv')
vehicle_reg[:5]
# Out:
#   Record Type                VIN Registration Class             City State  \
# 0        VEH   8995                             PAS  BUFFALO            NY
# 1        VEH   607SR2131A                       PAS  N SYRACUSE         NY
# 2        VEH   537LS7D46CT083476                PAS  NEWFANE            NY
# 3        VEH   53TBH2MC1BE900166                PAS  ROCKVILLE CTR      NY
# 4        VEH   53G1B4A47DB000347                PAS  BROOKLYN           NY
#
#      Zip        County  Model Year   Make Body Type Fuel Type  Unladen Weight  \
# 0  14207  ERIE                1913  DE/EL      2DSD  ELECTRIC            1100
# 1  13212  ONONDAGA            1977  CITI       2DSD  ELECTRIC            2590
# 2  14108  NIAGARA             2012  AZURE      SUBN  ELECTRIC            4005
# 3  11570  NASSAU              2011  THINK      2DSD  ELECTRIC            2348
# 4  11223  KINGS               2013  CODA       4DSD  ELECTRIC            3682
#
#    Maximum Gross Weight  Passengers Reg Valid Date Reg Expiration Date  Color  \
# 0                   NaN         NaN     05/31/2018          07/01/2020  MR
# 1                   NaN         NaN     11/21/2017          11/20/2019  RD
# 2                   NaN         NaN     05/16/2017          05/17/2019  WH
# 3                   NaN         NaN     04/18/2018          05/06/2020  RD
# 4                   NaN         NaN     08/08/2018          08/07/2020  BK
#
#   Scofflaw Indicator Suspension Indicator Revocation Indicator
# 0                  N                    N                    N
# 1                  N                    N                    N
# 2                  N                    N                    N
# 3                  N                    N                    N
# 4                  N                    N                    N

# %%
#Create a new df with only the counties for each registration
county_registrations = vehicle_reg[['County']]
county_registrations[:5]
#rename so it is easier to join later
#county1.columns = ['County']
#county1[:5]
# Out:
#          County
# 0  ERIE
# 1  ONONDAGA
# 2  NIAGARA
# 3  NASSAU
# 4  KINGS

# %%
#use groupby to organize the counties, then count how many times a couny appears in df
#Add a column for the number of times a county shows up in the df. This is the number of EV registered in the county
county['Number of Vehicles'] = ''
reg_county = county.groupby(['County'], as_index = False)
count_county = reg_county.agg({'Number of Vehicles':'count'}).sort_values(['Number of Vehicles','County'], ascending=[False, True])
count_county[:5]
# Out:
#           County  Number of Vehicles
# 59  WESTCHESTER                 1577
# 28  NASSAU                      1486
# 51  SUFFOLK                     1196
# 29  NEW YORK                     875
# 40  QUEENS                       456

# %%
#import Region data
from pandas import DataFrame
region = pd.read_excel(r'/Users/ceciliapershyn/CIS_512_Term_Project/county_to_region.xlsx')
region = DataFrame(region, columns=['Region_Code','Region','County'])
region
# Out:
#     Region_Code                Region        County
# 0             1           Long Island        Nassau
# 1             1           Long Island       Suffolk
# 2             2         New York City         Kings
# 3             2         New York City         Bronx
# 4             2         New York City      New York
# 5             2         New York City        Queens
# 6             2         New York City      Richmond
# 7             3   Lower Hudson Valley      Dutchess
# 8             3   Lower Hudson Valley        Orange
# 9             3   Lower Hudson Valley        Putnam
# 10            3   Lower Hudson Valley      Rockland
# 11            3   Lower Hudson Valley      Sullivan
# 12            3   Lower Hudson Valley        Ulster
# 13            3   Lower Hudson Valley   Westchester
# 14            4        Capital Region        Albany
# 15            4        Capital Region      Columbia
# 16            4        Capital Region      Delaware
# 17            4        Capital Region        Greene
# 18            4        Capital Region    Montgomery
# 19            4        Capital Region        Otsego
# 20            4        Capital Region    Rensselaer
# 21            4        Capital Region   Schenectady
# 22            4        Capital Region     Schoharie
# 23            5   Eastern Adirondacks       Clinton
# 24            5   Eastern Adirondacks         Essex
# 25            5   Eastern Adirondacks      Franklin
# 26            5   Eastern Adirondacks        Fulton
# 27            5   Eastern Adirondacks      Hamilton
# 28            5   Eastern Adirondacks      Saratoga
# 29            5   Eastern Adirondacks        Warren
# ..          ...                   ...           ...
# 32            6   Western Adirondacks     Jefferson
# 33            6   Western Adirondacks         Lewis
# 34            6   Western Adirondacks        Oneida
# 35            6   Western Adirondacks  St. Lawrence
# 36            7      Central New York        Broome
# 37            7      Central New York        Cayuga
# 38            7      Central New York      Chenango
# 39            7      Central New York      Cortland
# 40            7      Central New York       Madison
# 41            7      Central New York      Onondaga
# 42            7      Central New York        Oswego
# 43            7      Central New York          Tioa
# 44            7      Central New York      Tompkins
# 45            8  Western Finger Lakes       Chemung
# 46            8  Western Finger Lakes       Genesee
# 47            8  Western Finger Lakes    Livingston
# 48            8  Western Finger Lakes        Monroe
# 49            8  Western Finger Lakes       Ontario
# 50            8  Western Finger Lakes       Orleans
# 51            8  Western Finger Lakes      Schuyler
# 52            8  Western Finger Lakes        Seneca
# 53            8  Western Finger Lakes       Steuben
# 54            8  Western Finger Lakes         Wayne
# 55            8  Western Finger Lakes         Yates
# 56            9      Western New York      Allegany
# 57            9      Western New York    Chautauqua
# 58            9      Western New York   Cattaraugus
# 59            9      Western New York          Erie
# 60            9      Western New York       Niagara
# 61            9      Western New York       Wyoming
#
# [62 rows x 3 columns]

# %%
#convert County column to uppercase so it will match the County columns in other tables after join
region['County'] = region['County'].str.upper()
region.rename(index=str, columns={"County": "county"})
region[:5]
# Out:
#    Region_Code         Region    County
# 0            1    Long Island    NASSAU
# 1            1    Long Island   SUFFOLK
# 2            2  New York City     KINGS
# 3            2  New York City     BRONX
# 4            2  New York City  NEW YORK

# %%
#remove Region_Code
region = region[['County','Region']]
region[:5]
# Out:
#      County         Region
# 0    NASSAU    Long Island
# 1   SUFFOLK    Long Island
# 2     KINGS  New York City
# 3     BRONX  New York City
# 4  NEW YORK  New York City

# %%
#1st attempt to join
veh_count_reg = pd.merge_ordered(count_county, region, on='County', fill_method=None, how='outer')
veh_count_reg

#Question1: How might I be able to join this dataframe and get rid of NaN values?

#Edit: further down in the notebook I realize that it would be
#a better strategy to add the county to the region table before
#doing the group by.  This way, I can groupby the region 
#and get the number of vehicles per region(see below for example)
# Out:
#            County  Number of Vehicles                Region
# 0          ALBANY                 NaN        Capital Region
# 1    ALBANY                     226.0                   NaN
# 2        ALLEGANY                 NaN      Western New York
# 3    ALLEGANY                     2.0                   NaN
# 4           BRONX                 NaN         New York City
# 5    BRONX                       77.0                   NaN
# 6          BROOME                 NaN      Central New York
# 7    BROOME                      45.0                   NaN
# 8     CATTARAUGUS                 NaN      Western New York
# 9    CATTARAUGUS                  7.0                   NaN
# 10         CAYUGA                 NaN      Central New York
# 11   CAYUGA                      13.0                   NaN
# 12     CHAUTAUQUA                 NaN      Western New York
# 13   CHAUTAUQUA                  16.0                   NaN
# 14        CHEMUNG                 NaN  Western Finger Lakes
# 15   CHEMUNG                     21.0                   NaN
# 16       CHENANGO                 NaN      Central New York
# 17   CHENANGO                     7.0                   NaN
# 18        CLINTON                 NaN   Eastern Adirondacks
# 19   CLINTON                     21.0                   NaN
# 20       COLUMBIA                 NaN        Capital Region
# 21   COLUMBIA                    31.0                   NaN
# 22       CORTLAND                 NaN      Central New York
# 23   CORTLAND                     7.0                   NaN
# 24       DELAWARE                 NaN        Capital Region
# 25   DELAWARE                     9.0                   NaN
# 26       DUTCHESS                 NaN   Lower Hudson Valley
# 27   DUTCHESS                   202.0                   NaN
# 28           ERIE                 NaN      Western New York
# 29   ERIE                       283.0                   NaN
# ..            ...                 ...                   ...
# 94       SCHUYLER                 NaN  Western Finger Lakes
# 95   SCHUYLER                     8.0                   NaN
# 96         SENECA                 NaN  Western Finger Lakes
# 97   SENECA                       6.0                   NaN
# 98   ST LAWRENCE                  9.0                   NaN
# 99   ST. LAWRENCE                 NaN   Western Adirondacks
# 100       STEUBEN                 NaN  Western Finger Lakes
# 101  STEUBEN                     24.0                   NaN
# 102       SUFFOLK                 NaN           Long Island
# 103  SUFFOLK                   1196.0                   NaN
# 104      SULLIVAN                 NaN   Lower Hudson Valley
# 105  SULLIVAN                    21.0                   NaN
# 106          TIOA                 NaN      Central New York
# 107  TIOGA                       11.0                   NaN
# 108      TOMPKINS                 NaN      Central New York
# 109  TOMPKINS                   113.0                   NaN
# 110        ULSTER                 NaN   Lower Hudson Valley
# 111  ULSTER                     156.0                   NaN
# 112        WARREN                 NaN   Eastern Adirondacks
# 113  WARREN                      26.0                   NaN
# 114    WASHINGTON                 NaN   Eastern Adirondacks
# 115  WASHINGTON                  15.0                   NaN
# 116         WAYNE                 NaN  Western Finger Lakes
# 117  WAYNE                       15.0                   NaN
# 118   WESTCHESTER                 NaN   Lower Hudson Valley
# 119  WESTCHESTER               1577.0                   NaN
# 120       WYOMING                 NaN      Western New York
# 121  WYOMING                      3.0                   NaN
# 122         YATES                 NaN  Western Finger Lakes
# 123  YATES                        3.0                   NaN
#
# [124 rows x 3 columns]

# %%
#I'm creating a sample dataframe as an example of the output
#I am trying to achieve

sample = {'County':['Albany', 'Allegany', 'Columbia',  'Cattaragus', 'Clinton', 'Erie'], 
          '# of Veh':[226, 2, 31, 7, 21, 283], 
          'Region':['Capital', 'WNY', 'Capital', 'WNY', 'Eastern ADK', 'WNY' ]}
sample_veh_reg_count = DataFrame (sample, columns = ['County', '# of Veh', 'Region'])
sample_veh_reg_count
# Out:
#        County  # of Veh       Region
# 0      Albany       226      Capital
# 1    Allegany         2          WNY
# 2    Columbia        31      Capital
# 3  Cattaragus         7          WNY
# 4     Clinton        21  Eastern ADK
# 5        Erie       283          WNY

# %%
#The next step is to add together all the vehicles in each region
sample_veh_reg = sample_veh_reg_count[['# of Veh', 'Region']]
sample_veh_reg
# Out:
#    # of Veh       Region
# 0       226      Capital
# 1         2          WNY
# 2        31      Capital
# 3         7          WNY
# 4        21  Eastern ADK
# 5       283          WNY

# %%
sample_veh_reg = sample_veh_reg.groupby(['Region'], as_index = False)
sample_total_veh_region = sample_veh_reg.agg({'# of Veh':'count'}).sort_values(['# of Veh','Region'], ascending=[False, True])
sample_total_veh_region[:5]

#So this is just showing the number of times the region shows 
#up in the dataframe, which is not what I am looking for
# Out:
#         Region  # of Veh
# 2          WNY         3
# 0      Capital         2
# 1  Eastern ADK         1

# %%
#Maybe I should try to add the county to the region table BEFORE
#doing the initial groupby (which produces the # of vehicles/county).
#This way, I can do the group by on regions instead of counties

veh_count_reg = pd.merge_ordered(county1, region, on='County', fill_method=None, how='outer')
veh_count_reg

#The result is the region only shows up one time,
#the first time the county shows up in the dataframe
#How do i get it to match so that every time Albany appears in the
#dataframe, it is matched with "Capital Region"?
# Out:
#             County                Region
# 0           ALBANY        Capital Region
# 1     ALBANY                         NaN
# 2     ALBANY                         NaN
# 3     ALBANY                         NaN
# 4     ALBANY                         NaN
# 5     ALBANY                         NaN
# 6     ALBANY                         NaN
# 7     ALBANY                         NaN
# 8     ALBANY                         NaN
# 9     ALBANY                         NaN
# 10    ALBANY                         NaN
# 11    ALBANY                         NaN
# 12    ALBANY                         NaN
# 13    ALBANY                         NaN
# 14    ALBANY                         NaN
# 15    ALBANY                         NaN
# 16    ALBANY                         NaN
# 17    ALBANY                         NaN
# 18    ALBANY                         NaN
# 19    ALBANY                         NaN
# 20    ALBANY                         NaN
# 21    ALBANY                         NaN
# 22    ALBANY                         NaN
# 23    ALBANY                         NaN
# 24    ALBANY                         NaN
# 25    ALBANY                         NaN
# 26    ALBANY                         NaN
# 27    ALBANY                         NaN
# 28    ALBANY                         NaN
# 29    ALBANY                         NaN
# ...            ...                   ...
# 9254  WESTCHESTER                    NaN
# 9255  WESTCHESTER                    NaN
# 9256  WESTCHESTER                    NaN
# 9257  WESTCHESTER                    NaN
# 9258  WESTCHESTER                    NaN
# 9259  WESTCHESTER                    NaN
# 9260  WESTCHESTER                    NaN
# 9261  WESTCHESTER                    NaN
# 9262  WESTCHESTER                    NaN
# 9263  WESTCHESTER                    NaN
# 9264  WESTCHESTER                    NaN
# 9265  WESTCHESTER                    NaN
# 9266  WESTCHESTER                    NaN
# 9267  WESTCHESTER                    NaN
# 9268  WESTCHESTER                    NaN
# 9269  WESTCHESTER                    NaN
# 9270  WESTCHESTER                    NaN
# 9271  WESTCHESTER                    NaN
# 9272  WESTCHESTER                    NaN
# 9273  WESTCHESTER                    NaN
# 9274  WESTCHESTER                    NaN
# 9275  WESTCHESTER                    NaN
# 9276       WYOMING      Western New York
# 9277  WYOMING                        NaN
# 9278  WYOMING                        NaN
# 9279  WYOMING                        NaN
# 9280         YATES  Western Finger Lakes
# 9281  YATES                          NaN
# 9282  YATES                          NaN
# 9283  YATES                          NaN
#
# [9284 rows x 2 columns]

# %%
#This is another sample dataset to show my new desired outcome

sample2 = {'County':['Albany', 'Albany', 'Albany',  'Cattaragus', 'Erie', 'Clinton', 'Dutchess', 'Dutchess'], 
          'Region':['Capital', 'Capital', 'Capital', 'WNY', 'WNY', 'Eastern ADK', 'LHV', 'LHV'  ]}
sample_county_reg = DataFrame (sample2, columns = ['County', 'Region'])
sample_county_reg
# Out:
#        County       Region
# 0      Albany      Capital
# 1      Albany      Capital
# 2      Albany      Capital
# 3  Cattaragus          WNY
# 4        Erie          WNY
# 5     Clinton  Eastern ADK
# 6    Dutchess          LHV
# 7    Dutchess          LHV

# %%
reg = sample_county_reg[['Region']]
reg['# of Veh'] = ''

sample_county_reg = reg.groupby(['Region'], as_index = False)
sample_total_county_reg = sample_county_reg.agg({'# of Veh':'count'}).sort_values(['# of Veh','Region'], ascending=[False, True])
sample_total_county_reg

#The below table is my desired outcome for this portion of the project
# Out:
#         Region  # of Veh
# 0      Capital         3
# 2          LHV         2
# 3          WNY         2
# 1  Eastern ADK         1

# %%
#The above method would work, if I could figure out a way to give
#each county its corresponding region in the data table above
#I am thinking a iterative loop might be the best option?

# %%
#Question3: Any ideas why this code would turn up an empty dataframe?
v_c_reg = county_registrations.merge(region, how='inner', left_on='County', right_on='County', validate='many_to_many')
v_c_reg
# Out:
# Empty DataFrame
# Columns: [County, Region]
# Index: []

# %% [markdown]
# ### Repeat the above process for gas vehicles per county

# %%
all_reg = pd.read_csv('All_Vehicle_Registration_NYS.csv')
all_reg[:5]
# Out:
#   Record Type Fuel Type        County  Registration Class
# 0        BOAT  OTHER     CLINTON                       12
# 1        VEH   DIESEL    NEW YORK                    6862
# 2        BOAT  FLEX      ONONDAGA                      10
# 3        BOAT  FLEX      SCHUYLER                       2
# 4        BOAT  FLEX      LIVINGSTON                     3

# %%
#WHY IS THIS FILTER NOT WORKING?!?!?
car_reg = all_reg[all_reg['Record Type'] == 'VEH']
car_reg[:5]
# Out:
# Empty DataFrame
# Columns: [Record Type, Fuel Type, County, Registration Class]
# Index: []

# %% [markdown]
# # Charging Hubs

# %%
charge_hub = pd.read_csv('Electric_Vehicle_Charging_Stations_in_New_York.csv')
charge_hub.head()
# Out:
#   Fuel Type Code                                       Station Name  \
# 0           ELEC  Hudson Valley Community College - TEC-SMART Bu...
# 1           ELEC                                     EDISONPARKFAST
# 2           ELEC                                        CARCHARGING
# 3           ELEC                                        CARCHARGING
# 4           ELEC                                     EDISONPARKFAST
#
#   Street Address                            Intersection Directions      City  \
# 0  345 Hermes Rd                                                NaN     Malta
# 1    451 9th Ave   LOC #250 #2 LOT#250; ChargePoint America Program  New York
# 2  350 W 50th St  ICON MERCURY; Icon parking see attendant for a...  New York
# 3  310 W 39th St  ICON 310 W 39TH; Icon Parking systems see vale...  New York
# 4   50 W 44th St  LOC #100 LEVEL3; Located in basement level of ...  New York
#
#   State    ZIP  Plus4 Station Phone Status Code            ...              \
# 0    NY  12020    NaN  518-629-7075           E            ...
# 1    NY  10018    NaN  888-758-4389           E            ...
# 2    NY  10019    NaN  888-758-4389           E            ...
# 3    NY  10018    NaN  888-758-4389           E            ...
# 4    NY  10036    NaN  888-758-4389           E            ...
#
#     Latitude  Longitude Date Last Confirmed     ID               Updated At  \
# 0  42.971670 -73.774182          06/02/2017  36532  2018-02-06 21:00:03 UTC
# 1  40.754512 -73.995938          10/28/2018  36945  2018-10-28 09:03:02 UTC
# 2  40.763245 -73.988648          10/28/2018  37169  2018-10-28 09:03:02 UTC
# 3  40.755440 -73.992027          10/28/2018  38530  2018-10-28 09:03:02 UTC
# 4  40.755546 -73.982307          10/28/2018  38981  2018-10-28 09:03:02 UTC
#
#    Owner Type Code  Federal Agency ID  Federal Agency Name   Open Date  \
# 0               SG                NaN                  NaN  10/15/2010
# 1              NaN                NaN                  NaN         NaN
# 2              NaN                NaN                  NaN         NaN
# 3              NaN                NaN                  NaN         NaN
# 4              NaN                NaN                  NaN         NaN
#
#                     Location
# 0     (42.97167, -73.774182)
# 1    (40.754512, -73.995938)
# 2  (40.7632446, -73.9886475)
# 3  (40.7554398, -73.9920273)
# 4    (40.755546, -73.982307)
#
# [5 rows x 32 columns]

# %%
Zip = charge_hub[['ZIP', 'Latitude', 'Longitude']]
Zip[:4]
# Out:
#      ZIP   Latitude  Longitude
# 0  12020  42.971670 -73.774182
# 1  10018  40.754512 -73.995938
# 2  10019  40.763245 -73.988648
# 3  10018  40.755440 -73.992027

# %%
#upload zip/county cross reference data from NYS open data

upload = pd.read_csv('zip_county_cross_reference.csv')
upload['County Name'] = upload['County Name'].str.upper()

upload[:5]
# Out:
#   County Name  State FIPS  County Code  County FIPS  ZIP Code   File Date
# 0      ALBANY          36            1        36001     12046  07/25/2007
# 1      ALBANY          36            1        36001     12083  07/25/2007
# 2      ALBANY          36            1        36001     12085  07/25/2007
# 3      ALBANY          36            1        36001     12201  07/25/2007
# 4      ALBANY          36            1        36001     12203  07/25/2007

# %%
zip_county = upload[['County Name', 'ZIP Code']]
zip_county[:5]
# Out:
#   County Name  ZIP Code
# 0      ALBANY     12046
# 1      ALBANY     12083
# 2      ALBANY     12085
# 3      ALBANY     12201
# 4      ALBANY     12203

# %%
#join zip_county and Zip.  Output will be a datatable that will
#give county values to the zip codes where charge hubs are located

zip_co = Zip.merge(zip_county, how='inner', left_on='ZIP', right_on='ZIP Code', validate='many_to_many')
zip_co
# Out:
#         ZIP   Latitude  Longitude   County Name  ZIP Code
# 0     12020  42.971670 -73.774182      SARATOGA     12020
# 1     10018  40.754512 -73.995938      NEW YORK     10018
# 2     10018  40.755440 -73.992027      NEW YORK     10018
# 3     10018  40.756029 -73.992655      NEW YORK     10018
# 4     10018  40.756177 -73.990558      NEW YORK     10018
# 5     10018  40.751427 -73.986598      NEW YORK     10018
# 6     10019  40.763245 -73.988648      NEW YORK     10019
# 7     10019  40.768784 -73.983147      NEW YORK     10019
# 8     10019  40.770790 -73.988508      NEW YORK     10019
# 9     10019  40.768257 -73.989087      NEW YORK     10019
# 10    10019  40.761375 -73.985277      NEW YORK     10019
# 11    10019  40.756840 -73.967592      NEW YORK     10019
# 12    10019  40.766000 -73.982621      NEW YORK     10019
# 13    10019  40.763888 -73.974990      NEW YORK     10019
# 14    10019  40.769291 -73.992541      NEW YORK     10019
# 15    10019  40.770411 -73.990655      NEW YORK     10019
# 16    10019  40.764656 -73.976101      NEW YORK     10019
# 17    10019  40.766719 -73.979533      NEW YORK     10019
# 18    10019  40.764623 -73.976181      NEW YORK     10019
# 19    10019  40.764609 -73.979542      NEW YORK     10019
# 20    10019  40.768946 -73.984150      NEW YORK     10019
# 21    10019  40.764609 -73.979512      NEW YORK     10019
# 22    10019  40.765153 -73.984122      NEW YORK     10019
# 23    10019  40.765153 -73.984347      NEW YORK     10019
# 24    10019  40.768946 -73.984120      NEW YORK     10019
# 25    10019  40.766719 -73.979583      NEW YORK     10019
# 26    10019  40.762152 -73.985803      NEW YORK     10019
# 27    10019  40.764693 -73.982708      NEW YORK     10019
# 28    10019  40.763101 -73.981263      NEW YORK     10019
# 29    10019  40.767194 -73.984544      NEW YORK     10019
# ...     ...        ...        ...           ...       ...
# 1114  13088  43.100500 -76.206648      ONONDAGA     13088
# 1115  13088  43.101581 -76.207454      ONONDAGA     13088
# 1116  13088  43.101615 -76.187821      ONONDAGA     13088
# 1117  12075  42.270437 -73.593885      COLUMBIA     12075
# 1118  12075  42.270437 -73.593885      COLUMBIA     12075
# 1119  12045  42.472557 -73.790396        ALBANY     12045
# 1120  13669  44.718303 -75.455798  ST. LAWRENCE     13669
# 1121  11706  40.726926 -73.283143       SUFFOLK     11706
# 1122  10523  41.047509 -73.806341   WESTCHESTER     10523
# 1123  12043  42.670143 -74.507792        OTSEGO     12043
# 1124  12043  42.670143 -74.507792     SCHOHARIE     12043
# 1125  12514  41.825295 -73.770429      DUTCHESS     12514
# 1126  14870  42.170992 -77.107702      SCHUYLER     14870
# 1127  14870  42.170992 -77.107702       STEUBEN     14870
# 1128  11803  40.779271 -73.452744        NASSAU     11803
# 1129  11581  40.663272 -73.719248        NASSAU     11581
# 1130  12047  42.771298 -73.752656        ALBANY     12047
# 1131  14760  42.081885 -78.427994   CATTARAUGUS     14760
# 1132  11355  40.753624 -73.823573        QUEENS     11355
# 1133  11978  40.811928 -72.643211       SUFFOLK     11978
# 1134  14485  42.905520 -77.610606    LIVINGSTON     14485
# 1135  14485  42.905520 -77.610606       ONTARIO     14485
# 1136  11378  40.726786 -73.900158        QUEENS     11378
# 1137  12498  42.044798 -74.118166        ULSTER     12498
# 1138  12498  42.041481 -74.117992        ULSTER     12498
# 1139  11768  40.908117 -73.315463       SUFFOLK     11768
# 1140  13320  42.797294 -74.758022        OTSEGO     13320
# 1141  13320  42.797294 -74.758022     SCHOHARIE     13320
# 1142  13320  42.797294 -74.758022    MONTGOMERY     13320
# 1143  14086  42.886688 -78.664394          ERIE     14086
#
# [1144 rows x 5 columns]

# %%
county_hub = zip_co[['County Name']]
#county_hub['County Name'] = county_hub['County Name'].str.upper()
county_hub[:5]
# Out:
#   County Name
# 0    SARATOGA
# 1    NEW YORK
# 2    NEW YORK
# 3    NEW YORK
# 4    NEW YORK

# %%
hub_count = county_hub.merge(region, how='inner', left_on='County Name', right_on='County', validate='many_to_many')
hub_count
# Out:
# Empty DataFrame
# Columns: [County Name, Region_Code, Region, County]
# Index: []

# %%
reg_count_hub1 = county_reg[['Region']]
reg_count_hub1[:5]
# Out:
#                 Region
# 0  Eastern Adirondacks
# 1  Eastern Adirondacks
# 2  Eastern Adirondacks
# 3  Eastern Adirondacks
# 4  Eastern Adirondacks

# %%
reg_count_hub1['Number of Hubs'] = ''
reg_count_hub2 = reg_count_hub1.groupby(['Region'], as_index = False)
reg_count_hub = reg_count_hub2.agg({'Number of Hubs':'count'}).sort_values(['Number of Hubs','Region'], ascending=[False, True])
reg_count_hub
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                  Region  Number of Hubs
# 5         New York City             397
# 4   Lower Hudson Valley             161
# 0        Capital Region             127
# 3           Long Island             115
# 7  Western Finger Lakes              96
# 1      Central New York              84
# 2   Eastern Adirondacks              67
# 8      Western New York              62
# 6   Western Adirondacks              33

# %%
import seaborn as sns
ax = sns.barplot(x='Region', y='Number of Hubs', data=reg_count_hub)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40, ha='right')
plt.show()

# %%
#wondering if I can backtrack to the vehicle information and use the same 
#county_reg = county_hub.merge(region, how='inner', left_on='County Name', right_on='County', validate='many_to_many')
#code to merge county and region for the vehicle data?

# %%
#Question3: Any ideas why this code would turn up an empty dataframe?
v_c_reg = county_registrations.merge(region, how='inner', left_on='County', right_on='County', validate='many_to_many')
v_c_reg
# Out:
# Empty DataFrame
# Columns: [County, Region_Code, Region]
# Index: []

# %%
#group by: how many Hubs per county?
hcc = hub_count[['County', 'Region']]
hcc [:5]


hcc['Number of Hubs'] = ''
h_county = hcc.groupby(['Region', 'County'], as_index = False)
hub_county_count = h_county.agg({'Number of Hubs':'count'}).sort_values(['Number of Hubs','County'], ascending=[False, True])
#hub_county_count.groupby(['Region'], as_index = False)
hub_county_count[:5]
# Out:
# Empty DataFrame
# Columns: [Region, County, Number of Hubs]
# Index: []

# %%
import seaborn as sns
ax = sns.barplot(x = 'County',  
                   hue = 'Region',
                   palette = 'pastel',
                   data=hub_county_count)
ax.figure.set_size_inches(20,15)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40, ha='right')
#ax.axes.set_title("Management of Tanzania Rural Water Sources",fontsize=18)
ax.set_xlabel("County",fontsize=14)
#ax.set_ylabel("Type of Management",fontsize=12)
ax.tick_params(labelsize=8)
ax_seg = plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0.)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Greenhouse Gas Emissions

# %%
e = pd.read_csv('Greenhouse_Gas_Emissions_From_Gasoline.csv')
e
# Out:
#    Year Fuel Type  Transportation  Electricity Generation  Residential  \
# 0  2015  Gasoline           53.06                     NaN          NaN
# 1  2014  Gasoline           53.58                     NaN          NaN
# 2  2013  Gasoline           51.27                     NaN          NaN
# 3  2012  Gasoline           48.72                     NaN          NaN
# 4  2011  Gasoline           55.09                     NaN          NaN
# 5  2010  Gasoline           55.43                     NaN          NaN
#
#    Commercial  Industrial  Total CO2 Emissions  Percent of Total CO2 Emissions
# 0         NaN         NaN                53.06                            29.8
# 1         NaN         NaN                53.58                            29.8
# 2         NaN         NaN                51.27                            28.7
# 3         NaN         NaN                48.72                            28.6
# 4         NaN         NaN                55.09                            30.1
# 5         NaN         NaN                55.43                            29.0

# %%
emissions = e[['Year', 'Total CO2 Emissions', 'Percent of Total CO2 Emissions']]
emissions
# Out:
#    Year  Total CO2 Emissions  Percent of Total CO2 Emissions
# 0  2015                53.06                            29.8
# 1  2014                53.58                            29.8
# 2  2013                51.27                            28.7
# 3  2012                48.72                            28.6
# 4  2011                55.09                            30.1
# 5  2010                55.43                            29.0

# %%
import seaborn as sns
p1=sns.kdeplot(emissions['Total CO2 Emissions'], shade=True, color='r')

# %%
pl=sns.kdeplot(emissions['Percent of Total CO2 Emissions'], shade=True, color='b')

# %%
plt.plot('Year', 'Total CO2 Emissions', data=emissions, linestyle='-', marker='o', color='r')
plt.plot('Year', 'Percent of Total CO2 Emissions', data=emissions, linestyle='-', marker='o', color='orange')

# %% [markdown]
# # Charge Hubs per Sq Mile in Region (or county?)

# %%
#upload land area data from health.ny.gov/statistics

la = pd.read_csv('nys_population_density_2006.csv')
la[:5]
# Out:
#      County 2006 Population Estimate 2000 Census Population  \
# 0     Bronx                1,361,473              1,332,650
# 1     Kings                2,508,820              2,465,326
# 2  New York                1,611,581              1,537,195
# 3    Queens                2,255,175              2,229,379
# 4  Richmond                  477,377                443,728
#
#    2000 Land Area Square Miles  2006 Population Density1
# 0                        42.03                  32395.16
# 1                        70.61                  35532.65
# 2                        22.96                  70179.35
# 3                       109.24                  20645.13
# 4                        58.48                   8163.27

# %%
county_area = la[['County', '2000 Land Area Square Miles']]
county_area['County'] = county_area['County'].str.upper()
county_area = county_area.sort_values(['County'], ascending = True)

county_area = county_area.rename(index=str, columns={'2000 Land Area Square Miles':'Land Area (Sq Mi)'})

county_area
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          County  Land Area (Sq Mi)
# 5        ALBANY             523.45
# 6      ALLEGANY            1030.22
# 0         BRONX              42.03
# 7        BROOME             706.82
# 8   CATTARAUGUS            1309.85
# 9        CAYUGA             693.18
# 10   CHAUTAUQUA            1062.05
# 11      CHEMUNG             408.17
# 12     CHENANGO             894.36
# 13      CLINTON            1038.95
# 14     COLUMBIA             635.73
# 15     CORTLAND             499.65
# 16     DELAWARE            1446.37
# 17     DUTCHESS             801.59
# 18         ERIE            1044.21
# 19        ESSEX            1796.80
# 20     FRANKLIN            1631.49
# 21       FULTON             496.17
# 22      GENESEE             494.11
# 23       GREENE             647.75
# 24     HAMILTON            1720.39
# 25     HERKIMER            1411.25
# 26    JEFFERSON            1272.20
# 1         KINGS              70.61
# 27        LEWIS            1275.42
# 28   LIVINGSTON             632.13
# 29      MADISON             655.86
# 30       MONROE             659.29
# 31   MONTGOMERY             404.82
# 32       NASSAU             286.69
# ..          ...                ...
# 34       ONEIDA            1212.70
# 35     ONONDAGA             780.29
# 36      ONTARIO             644.38
# 37       ORANGE             816.34
# 38      ORLEANS             391.40
# 39       OSWEGO             953.30
# 40       OTSEGO            1002.80
# 41       PUTNAM             231.28
# 3        QUEENS             109.24
# 42   RENSSELAER             653.96
# 4      RICHMOND              58.48
# 43     ROCKLAND             174.22
# 45     SARATOGA             811.84
# 46  SCHENECTADY             206.10
# 47    SCHOHARIE             622.02
# 48     SCHUYLER             328.71
# 49       SENECA             324.91
# 44  ST LAWRENCE            2685.60
# 50      STEUBEN            1392.64
# 51      SUFFOLK             912.20
# 52     SULLIVAN             969.71
# 53        TIOGA             518.69
# 54     TOMPKINS             476.05
# 55       ULSTER            1126.48
# 56       WARREN             869.29
# 57   WASHINGTON             835.44
# 58        WAYNE             604.21
# 59  WESTCHESTER             432.82
# 60      WYOMING             592.91
# 61        YATES             338.24
#
# [62 rows x 2 columns]

# %%
#merge county_area and region

county_area_region = county_area.merge(region, how='inner', left_on='County', right_on='County', validate='one_to_many')
county_area_region[:5]
# Out:
#         County  Land Area (Sq Mi)            Region
# 0       ALBANY             523.45    Capital Region
# 1     ALLEGANY            1030.22  Western New York
# 2        BRONX              42.03     New York City
# 3       BROOME             706.82  Central New York
# 4  CATTARAUGUS            1309.85  Western New York

# %%
a = county_area_region.groupby(['Region', 'County'])[['Land Area (Sq Mi)']].sum()
a
# Out:
#                                   Land Area (Sq Mi)
# Region               County
# Capital Region       ALBANY                  523.45
#                      COLUMBIA                635.73
#                      DELAWARE               1446.37
#                      GREENE                  647.75
#                      MONTGOMERY              404.82
#                      OTSEGO                 1002.80
#                      RENSSELAER              653.96
#                      SCHENECTADY             206.10
#                      SCHOHARIE               622.02
# Central New York     BROOME                  706.82
#                      CAYUGA                  693.18
#                      CHENANGO                894.36
#                      CORTLAND                499.65
#                      MADISON                 655.86
#                      ONONDAGA                780.29
#                      OSWEGO                  953.30
#                      TOMPKINS                476.05
# Eastern Adirondacks  CLINTON                1038.95
#                      ESSEX                  1796.80
#                      FRANKLIN               1631.49
#                      FULTON                  496.17
#                      HAMILTON               1720.39
#                      SARATOGA                811.84
#                      WARREN                  869.29
#                      WASHINGTON              835.44
# Long Island          NASSAU                  286.69
#                      SUFFOLK                 912.20
# Lower Hudson Valley  DUTCHESS                801.59
#                      ORANGE                  816.34
#                      PUTNAM                  231.28
#                      ROCKLAND                174.22
#                      SULLIVAN                969.71
#                      ULSTER                 1126.48
#                      WESTCHESTER             432.82
# New York City        BRONX                    42.03
#                      KINGS                    70.61
#                      NEW YORK                 22.96
#                      QUEENS                  109.24
#                      RICHMOND                 58.48
# Western Adirondacks  HERKIMER               1411.25
#                      JEFFERSON              1272.20
#                      LEWIS                  1275.42
#                      ONEIDA                 1212.70
# Western Finger Lakes CHEMUNG                 408.17
#                      GENESEE                 494.11
#                      LIVINGSTON              632.13
#                      MONROE                  659.29
#                      ONTARIO                 644.38
#                      ORLEANS                 391.40
#                      SCHUYLER                328.71
#                      SENECA                  324.91
#                      STEUBEN                1392.64
#                      WAYNE                   604.21
#                      YATES                   338.24
# Western New York     ALLEGANY               1030.22
#                      CATTARAUGUS            1309.85
#                      CHAUTAUQUA             1062.05
#                      ERIE                   1044.21
#                      NIAGARA                 522.95
#                      WYOMING                 592.91

# %%
b = a.merge(hub_county_count, how='inner', left_on='County', right_on='County', validate='one_to_one')
b
# Out:
#          County  Land Area (Sq Mi)                Region  Number of Hubs
# 0        ALBANY             523.45        Capital Region              51
# 1      COLUMBIA             635.73        Capital Region              12
# 2      DELAWARE            1446.37        Capital Region               8
# 3        GREENE             647.75        Capital Region               4
# 4    MONTGOMERY             404.82        Capital Region               7
# 5        OTSEGO            1002.80        Capital Region               8
# 6    RENSSELAER             653.96        Capital Region              13
# 7   SCHENECTADY             206.10        Capital Region              21
# 8     SCHOHARIE             622.02        Capital Region               3
# 9        BROOME             706.82      Central New York               9
# 10       CAYUGA             693.18      Central New York               8
# 11     CORTLAND             499.65      Central New York               2
# 12      MADISON             655.86      Central New York               7
# 13     ONONDAGA             780.29      Central New York              35
# 14       OSWEGO             953.30      Central New York               1
# 15     TOMPKINS             476.05      Central New York              22
# 16      CLINTON            1038.95   Eastern Adirondacks               8
# 17        ESSEX            1796.80   Eastern Adirondacks               6
# 18     FRANKLIN            1631.49   Eastern Adirondacks               3
# 19       FULTON             496.17   Eastern Adirondacks               6
# 20     HAMILTON            1720.39   Eastern Adirondacks               1
# 21     SARATOGA             811.84   Eastern Adirondacks              26
# 22       WARREN             869.29   Eastern Adirondacks              11
# 23   WASHINGTON             835.44   Eastern Adirondacks               6
# 24       NASSAU             286.69           Long Island              37
# 25      SUFFOLK             912.20           Long Island              78
# 26     DUTCHESS             801.59   Lower Hudson Valley              20
# 27       ORANGE             816.34   Lower Hudson Valley              18
# 28       PUTNAM             231.28   Lower Hudson Valley               2
# 29     ROCKLAND             174.22   Lower Hudson Valley               6
# 30     SULLIVAN             969.71   Lower Hudson Valley               9
# 31       ULSTER            1126.48   Lower Hudson Valley              44
# 32  WESTCHESTER             432.82   Lower Hudson Valley              62
# 33        BRONX              42.03         New York City              11
# 34        KINGS              70.61         New York City              42
# 35     NEW YORK              22.96         New York City             306
# 36       QUEENS             109.24         New York City              34
# 37     RICHMOND              58.48         New York City               4
# 38     HERKIMER            1411.25   Western Adirondacks               6
# 39    JEFFERSON            1272.20   Western Adirondacks               7
# 40       ONEIDA            1212.70   Western Adirondacks              13
# 41      CHEMUNG             408.17  Western Finger Lakes               2
# 42      GENESEE             494.11  Western Finger Lakes               3
# 43   LIVINGSTON             632.13  Western Finger Lakes               4
# 44       MONROE             659.29  Western Finger Lakes              43
# 45      ONTARIO             644.38  Western Finger Lakes              11
# 46      ORLEANS             391.40  Western Finger Lakes               2
# 47     SCHUYLER             328.71  Western Finger Lakes               7
# 48       SENECA             324.91  Western Finger Lakes               7
# 49      STEUBEN            1392.64  Western Finger Lakes               2
# 50        WAYNE             604.21  Western Finger Lakes              11
# 51        YATES             338.24  Western Finger Lakes               4
# 52  CATTARAUGUS            1309.85      Western New York               2
# 53   CHAUTAUQUA            1062.05      Western New York               6
# 54         ERIE            1044.21      Western New York              43
# 55      NIAGARA             522.95      Western New York               9
# 56      WYOMING             592.91      Western New York               2

# %%
c = b.groupby(['Region', 'County'])[['Land Area (Sq Mi)', 'Number of Hubs']].sum()
c[:5]
# Out:
#                            Land Area (Sq Mi)  Number of Hubs
# Region         County
# Capital Region ALBANY                 523.45              51
#                COLUMBIA               635.73              12
#                DELAWARE              1446.37               8
#                GREENE                 647.75               4
#                MONTGOMERY             404.82               7

# %%
c['Hub Density per sq. mile'] = c['Number of Hubs'] / c['Land Area (Sq Mi)']
c
#it would be awesome if I can sort this table by hub density within each region
# Out:
#                                   Land Area (Sq Mi)  Number of Hubs  \
# Region               County
# Capital Region       ALBANY                  523.45              51
#                      COLUMBIA                635.73              12
#                      DELAWARE               1446.37               8
#                      GREENE                  647.75               4
#                      MONTGOMERY              404.82               7
#                      OTSEGO                 1002.80               8
#                      RENSSELAER              653.96              13
#                      SCHENECTADY             206.10              21
#                      SCHOHARIE               622.02               3
# Central New York     BROOME                  706.82               9
#                      CAYUGA                  693.18               8
#                      CORTLAND                499.65               2
#                      MADISON                 655.86               7
#                      ONONDAGA                780.29              35
#                      OSWEGO                  953.30               1
#                      TOMPKINS                476.05              22
# Eastern Adirondacks  CLINTON                1038.95               8
#                      ESSEX                  1796.80               6
#                      FRANKLIN               1631.49               3
#                      FULTON                  496.17               6
#                      HAMILTON               1720.39               1
#                      SARATOGA                811.84              26
#                      WARREN                  869.29              11
#                      WASHINGTON              835.44               6
# Long Island          NASSAU                  286.69              37
#                      SUFFOLK                 912.20              78
# Lower Hudson Valley  DUTCHESS                801.59              20
#                      ORANGE                  816.34              18
#                      PUTNAM                  231.28               2
#                      ROCKLAND                174.22               6
#                      SULLIVAN                969.71               9
#                      ULSTER                 1126.48              44
#                      WESTCHESTER             432.82              62
# New York City        BRONX                    42.03              11
#                      KINGS                    70.61              42
#                      NEW YORK                 22.96             306
#                      QUEENS                  109.24              34
#                      RICHMOND                 58.48               4
# Western Adirondacks  HERKIMER               1411.25               6
#                      JEFFERSON              1272.20               7
#                      ONEIDA                 1212.70              13
# Western Finger Lakes CHEMUNG                 408.17               2
#                      GENESEE                 494.11               3
#                      LIVINGSTON              632.13               4
#                      MONROE                  659.29              43
#                      ONTARIO                 644.38              11
#                      ORLEANS                 391.40               2
#                      SCHUYLER                328.71               7
#                      SENECA                  324.91               7
#                      STEUBEN                1392.64               2
#                      WAYNE                   604.21              11
#                      YATES                   338.24               4
# Western New York     CATTARAUGUS            1309.85               2
#                      CHAUTAUQUA             1062.05               6
#                      ERIE                   1044.21              43
#                      NIAGARA                 522.95               9
#                      WYOMING                 592.91               2
#
#                                   Hub Density per sq. mile
# Region               County
# Capital Region       ALBANY                       0.097431
#                      COLUMBIA                     0.018876
#                      DELAWARE                     0.005531
#                      GREENE                       0.006175
#                      MONTGOMERY                   0.017292
#                      OTSEGO                       0.007978
#                      RENSSELAER                   0.019879
#                      SCHENECTADY                  0.101892
#                      SCHOHARIE                    0.004823
# Central New York     BROOME                       0.012733
#                      CAYUGA                       0.011541
#                      CORTLAND                     0.004003
#                      MADISON                      0.010673
#                      ONONDAGA                     0.044855
#                      OSWEGO                       0.001049
#                      TOMPKINS                     0.046214
# Eastern Adirondacks  CLINTON                      0.007700
#                      ESSEX                        0.003339
#                      FRANKLIN                     0.001839
#                      FULTON                       0.012093
#                      HAMILTON                     0.000581
#                      SARATOGA                     0.032026
#                      WARREN                       0.012654
#                      WASHINGTON                   0.007182
# Long Island          NASSAU                       0.129059
#                      SUFFOLK                      0.085508
# Lower Hudson Valley  DUTCHESS                     0.024950
#                      ORANGE                       0.022050
#                      PUTNAM                       0.008648
#                      ROCKLAND                     0.034439
#                      SULLIVAN                     0.009281
#                      ULSTER                       0.039060
#                      WESTCHESTER                  0.143247
# New York City        BRONX                        0.261718
#                      KINGS                        0.594817
#                      NEW YORK                    13.327526
#                      QUEENS                       0.311241
#                      RICHMOND                     0.068399
# Western Adirondacks  HERKIMER                     0.004252
#                      JEFFERSON                    0.005502
#                      ONEIDA                       0.010720
# Western Finger Lakes CHEMUNG                      0.004900
#                      GENESEE                      0.006072
#                      LIVINGSTON                   0.006328
#                      MONROE                       0.065222
#                      ONTARIO                      0.017071
#                      ORLEANS                      0.005110
#                      SCHUYLER                     0.021295
#                      SENECA                       0.021544
#                      STEUBEN                      0.001436
#                      WAYNE                        0.018206
#                      YATES                        0.011826
# Western New York     CATTARAUGUS                  0.001527
#                      CHAUTAUQUA                   0.005649
#                      ERIE                         0.041179
#                      NIAGARA                      0.017210
#                      WYOMING                      0.003373

# %% [markdown]
# # Population Density and Income per County per Region

# %%
pop_dense = la[['County','2006 Population Density1']]
pop_dense[:5]
# Out:
#      County  2006 Population Density1
# 0     Bronx                  32395.16
# 1     Kings                  35532.65
# 2  New York                  70179.35
# 3    Queens                  20645.13
# 4  Richmond                   8163.27

# %%
pop_dense ['County'] = pop_dense['County'].str.upper()
pop_dense = pop_dense.sort_values(['County'], ascending = True)

pop_dense = pop_dense.rename(index=str, columns={'2006 Population Density1':'Population Density'})

pop_dense[:5]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         County  Population Density
# 5       ALBANY              568.46
# 6     ALLEGANY               48.79
# 0        BRONX            32395.16
# 7       BROOME              277.68
# 8  CATTARAUGUS               62.25

# %%
cpdr = c.merge(pop_dense, how='inner', left_on='County', right_on='County', validate = 'one_to_one')
cpdr
# Out:
#          County  Land Area (Sq Mi)  Number of Hubs  Hub Density per sq. mile  \
# 0        ALBANY             523.45              51                  0.097431
# 1      COLUMBIA             635.73              12                  0.018876
# 2      DELAWARE            1446.37               8                  0.005531
# 3        GREENE             647.75               4                  0.006175
# 4    MONTGOMERY             404.82               7                  0.017292
# 5        OTSEGO            1002.80               8                  0.007978
# 6    RENSSELAER             653.96              13                  0.019879
# 7   SCHENECTADY             206.10              21                  0.101892
# 8     SCHOHARIE             622.02               3                  0.004823
# 9        BROOME             706.82               9                  0.012733
# 10       CAYUGA             693.18               8                  0.011541
# 11     CORTLAND             499.65               2                  0.004003
# 12      MADISON             655.86               7                  0.010673
# 13     ONONDAGA             780.29              35                  0.044855
# 14       OSWEGO             953.30               1                  0.001049
# 15     TOMPKINS             476.05              22                  0.046214
# 16      CLINTON            1038.95               8                  0.007700
# 17        ESSEX            1796.80               6                  0.003339
# 18     FRANKLIN            1631.49               3                  0.001839
# 19       FULTON             496.17               6                  0.012093
# 20     HAMILTON            1720.39               1                  0.000581
# 21     SARATOGA             811.84              26                  0.032026
# 22       WARREN             869.29              11                  0.012654
# 23   WASHINGTON             835.44               6                  0.007182
# 24       NASSAU             286.69              37                  0.129059
# 25      SUFFOLK             912.20              78                  0.085508
# 26     DUTCHESS             801.59              20                  0.024950
# 27       ORANGE             816.34              18                  0.022050
# 28       PUTNAM             231.28               2                  0.008648
# 29     ROCKLAND             174.22               6                  0.034439
# 30     SULLIVAN             969.71               9                  0.009281
# 31       ULSTER            1126.48              44                  0.039060
# 32  WESTCHESTER             432.82              62                  0.143247
# 33        BRONX              42.03              11                  0.261718
# 34        KINGS              70.61              42                  0.594817
# 35     NEW YORK              22.96             306                 13.327526
# 36       QUEENS             109.24              34                  0.311241
# 37     RICHMOND              58.48               4                  0.068399
# 38     HERKIMER            1411.25               6                  0.004252
# 39    JEFFERSON            1272.20               7                  0.005502
# 40       ONEIDA            1212.70              13                  0.010720
# 41      CHEMUNG             408.17               2                  0.004900
# 42      GENESEE             494.11               3                  0.006072
# 43   LIVINGSTON             632.13               4                  0.006328
# 44       MONROE             659.29              43                  0.065222
# 45      ONTARIO             644.38              11                  0.017071
# 46      ORLEANS             391.40               2                  0.005110
# 47     SCHUYLER             328.71               7                  0.021295
# 48       SENECA             324.91               7                  0.021544
# 49      STEUBEN            1392.64               2                  0.001436
# 50        WAYNE             604.21              11                  0.018206
# 51        YATES             338.24               4                  0.011826
# 52  CATTARAUGUS            1309.85               2                  0.001527
# 53   CHAUTAUQUA            1062.05               6                  0.005649
# 54         ERIE            1044.21              43                  0.041179
# 55      NIAGARA             522.95               9                  0.017210
# 56      WYOMING             592.91               2                  0.003373
#
#     Population Density
# 0               568.46
# 1                99.03
# 2                32.48
# 3                76.92
# 4               121.32
# 5                62.41
# 6               237.46
# 7               729.93
# 8                51.76
# 9               277.68
# 10              117.20
# 11               97.03
# 12              107.03
# 13              585.39
# 14              129.11
# 15              210.92
# 16               79.09
# 17               21.51
# 18               31.24
# 19              111.73
# 20                3.00
# 21              265.41
# 22               76.02
# 23               75.85
# 24             4623.99
# 25             1611.18
# 26              368.20
# 27              461.07
# 28              434.98
# 29             1693.07
# 30               78.98
# 31              162.22
# 32             2193.40
# 33            32395.16
# 34            35532.65
# 35            70179.35
# 36            20645.13
# 37             8163.27
# 38               44.88
# 39               89.82
# 40              192.92
# 41              217.17
# 42              119.06
# 43              101.52
# 44             1108.47
# 45              161.94
# 46              110.41
# 47               59.06
# 48              106.87
# 49               70.54
# 50              153.74
# 51               73.12
# 52               62.25
# 53              127.45
# 54              882.38
# 55              413.29
# 56               71.87

# %%
# add income

income_tax_full = pd.read_csv('Income_Tax_NYS.csv')
income_tax_full[:5]
# Out:
#    Tax Year Place of Residence Income Class  Disclosure Number of All Returns  \
# 0      2014             Queens        Total         NaN             1,070,559
# 1      2014              Bronx        Total         NaN               616,640
# 2      2014              Kings        Total         NaN             1,138,249
# 3      2014          Manhattan        Total         NaN               885,829
# 4      2014           Richmond        Total         NaN               207,277
#
#   NY AGI of All Returns (in thousands) *  \
# 0                          46,877,014.17
# 1                          19,385,425.79
# 2                          56,877,626.01
# 3                         177,432,813.50
# 4                          12,207,326.06
#
#   Deductions of All Returns (in thousands)  \
# 0                            11,299,606.33
# 1                             5,559,529.02
# 2                            11,787,784.05
# 3                            11,714,664.78
# 4                             2,486,549.94
#
#   Dependent Exemptions of All Returns (in thousands)  \
# 0                                         547,842.96
# 1                                         361,780.32
# 2                                         608,940.23
# 3                                         283,670.65
# 4                                         115,486.19
#
#   Taxable Income of All Returns (in thousands)  \
# 0                                35,511,722.05
# 1                                13,560,902.73
# 2                                45,595,461.37
# 3                               170,057,039.82
# 4                                 9,737,467.62
#
#   Tax Before Credits of All Returns (in thousands)  \
# 0                                     2,091,689.64
# 1                                       758,348.19
# 2                                     2,848,028.68
# 3                                    13,132,236.96
# 4                                       593,706.07
#
#   Tax Liability of All Returns (in thousands) **  \
# 0                                   1,746,939.71
# 1                                     482,226.93
# 2                                   2,338,423.78
# 3                                  12,317,382.20
# 4                                     508,957.21
#
#    Place of Residence Sort Order  Income Class Sort Order
# 0                              4                       14
# 1                              1                       14
# 2                              2                       14
# 3                              3                       14
# 4                              5                       14

# %%
income_tax = income_tax_full[['Place of Residence', 'Taxable Income of All Returns (in thousands)']]
income_tax = income_tax.rename(index=str, columns={'Taxable Income of All Returns (in thousands)':'Total County Income'})
income_tax[:5]
# Out:
#   Place of Residence Total County Income
# 0             Queens       35,511,722.05
# 1              Bronx       13,560,902.73
# 2              Kings       45,595,461.37
# 3          Manhattan      170,057,039.82
# 4           Richmond        9,737,467.62

# %%
income_tax = income_tax[['Place of Residence']]
income_tax['Place of Residence'] = income_tax['Place of Residence'].str.upper()
income_tax[:5]
# Out:
#   Place of Residence
# 0             QUEENS
# 1              BRONX
# 2              KINGS
# 3          MANHATTAN
# 4           RICHMOND

# %%
income_tax_series = income_tax['Total County Income'].str.replace(',', '')
income_tax_series[:5]
# Out:
# 0     35511722.05
# 1     13560902.73
# 2     45595461.37
# 3    170057039.82
# 4      9737467.62
# Name: Total County Income, dtype: object

# %%
income_tax1 = income_tax_series.to_frame()
income_tax1[:5]
# Out:
#   Total County Income
# 0         35511722.05
# 1         13560902.73
# 2         45595461.37
# 3        170057039.82
# 4          9737467.62

# %%
income_tax1['Total County Income'] = income_tax1['Total County Income'].astype(float)
income_tax1[:5]
# Out:
#    Total County Income
# 0         3.551172e+07
# 1         1.356090e+07
# 2         4.559546e+07
# 3         1.700570e+08
# 4         9.737468e+06

# %%
frames = [income_tax, income_tax1]
income_tax2 = pd.concat(frames, axis=1, join='outer', sort=True)
income_tax2[:5]
# Out:
#    Place of Residence  Total County Income
# 0              QUEENS          35511722.05
# 1               BRONX          13560902.73
# 10         CHAUTAUQUA           1626573.57
# 11            CHEMUNG           1327083.37
# 12           CHENANGO            623704.01

# %%
pop = la[['2006 Population Estimate', 'County']]
pop ['County'] = pop['County'].str.upper()
pop = pop.sort_values(['County'], ascending = True)

pop = pop.rename(index=str, columns={'2006 Population Estimate':'County Population'})

pop[:5]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   County Population       County
# 5           297,556       ALBANY
# 6            50,267     ALLEGANY
# 0         1,361,473        BRONX
# 7           196,269       BROOME
# 8            81,534  CATTARAUGUS

# %%
income_pop = income_tax2.merge(pop, how='inner', left_on='Place of Residence', right_on='County', validate = 'one_to_one')
income_pop[:5]
# Out:
#   Place of Residence  Total County Income County Population      County
# 0             QUEENS          35511722.05         2,255,175      QUEENS
# 1              BRONX          13560902.73         1,361,473       BRONX
# 2         CHAUTAUQUA           1626573.57           135,357  CHAUTAUQUA
# 3            CHEMUNG           1327083.37            88,641     CHEMUNG
# 4           CHENANGO            623704.01            51,787    CHENANGO

# %%
#restart and run all, this should work
income_pop['County Population'] = income_pop['County Population'].str.replace(',', '')
income_pop['County Population'] = income_pop['County Population'].astype(float)
income_pop[:5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-371-f228dc9382c8> in <module>()
# ----> 1 income_pop['County Population'] = income_pop['County Population'].str.replace(',', '')
#       2 income_pop['County Population'] = income_pop['County Population'].astype(float)
#       3 income_pop[:5]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
#     133         # Replace the property with the accessor object. Inspired by:
#     134         # http://www.pydanny.com/cached-property.html
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/strings.py in _validate(data)
#    1915             # (instead of test for object dtype), but that isn't practical for
#    1916             # performance reasons until we have a str dtype (GH 9343)
# -> 1917             raise AttributeError("Can only use .str accessor with string "
#    1918                                  "values, which use np.object_ dtype in "
#    1919                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
income_pop['Total County Income'] = income_pop['Total County Income'] * 1000
income_pop[:5]
# Out:
#   Place of Residence  Total County Income  County Population      County
# 0             QUEENS         3.551172e+13          2255175.0      QUEENS
# 1              BRONX         1.356090e+13          1361473.0       BRONX
# 2         CHAUTAUQUA         1.626574e+12           135357.0  CHAUTAUQUA
# 3            CHEMUNG         1.327083e+12            88641.0     CHEMUNG
# 4           CHENANGO         6.237040e+11            51787.0    CHENANGO

# %%
income_pop['Average Income in County'] = income_pop['Total County Income'] / income_pop['County Population']
income_pop[:5]
# Out:
#   Place of Residence  Total County Income  County Population      County  \
# 0             QUEENS         3.551172e+13          2255175.0      QUEENS
# 1              BRONX         1.356090e+13          1361473.0       BRONX
# 2         CHAUTAUQUA         1.626574e+12           135357.0  CHAUTAUQUA
# 3            CHEMUNG         1.327083e+12            88641.0     CHEMUNG
# 4           CHENANGO         6.237040e+11            51787.0    CHENANGO
#
#    Average Income in County
# 0              1.574677e+07
# 1              9.960464e+06
# 2              1.201692e+07
# 3              1.497144e+07
# 4              1.204364e+07
