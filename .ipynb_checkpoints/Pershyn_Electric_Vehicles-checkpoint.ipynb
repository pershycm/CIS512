# %% [markdown]
# # Where Should There Be More Electric Charging Hubs in New York State?
# ### Cecilia Pershyn
# #### CIS512
#
#
# New York State is a leading state in clean and renewable energy, with a commitment to have 50% of the state’s electricity supplied by renewable sources by 2030. Thanks to impressive growth in solar, wind, hydro and biomass power in New York State, plug-in electric vehicles (EVs) have particularly low greenhouse gas emissions here.
#
# EVs are a cheap and clean alternative to gas-fueled vehicles. However, small battery storage capacity limits the amount of electric fuel that can be carried on board the vehicle.  In order to make the use of EVs more convenient, and help extend vehicle mileage, there is a need to expand the electric power grid and create more public fueling stations.
#
# In this study I will look at vehicle registrations in NYS to determine where electric vehicles are registered.  I will look at where charging ports are located in the state and compare to the zip codes with high electric vehicle registrations to determine which zip codes have the highest demand for new charging ports.
#
# Data Sources:
#
# Data on Charging Stations
# https://data.ny.gov/d/7rrd-248n?category=Energy-Environment&view_name=Electric-Vehicle-Charging-Stations-in-New-York
#
# Data on Electric Vehicle Registration
# https://data.ny.gov/d/uu25-czyc?category=Transportation&view_name=Electric-Vehicles-per-County
#
#
# Bibliography:
#
# How New York Uses Renewable Energy. (n.d.). Retrieved from http://www.dec.ny.gov/energy/83070.html
# Date Visited: 10/29/18
#
# How New York Uses Renewable Energy. (n.d.). Retrieved from http://www.dec.ny.gov/energy/83070.html
# Date Visited: 10/29/18

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

#use this function later in notebook to change NaN in "complete" data frame to 0
def fix_count(x):
    if x=='NaN':
        x=0
    elif x=='':
        x=0
    elif type(x) == type(8.8):
        x=0
    return int(x)
#This method did not work.  I attempted to read the csv using a converter, but then realized
#the count, where the NaN occurs, does not happen with the original csv file, but later when 
#I combine the dataframes.  So I will work on converting the NaN later.

sns.set(style="darkgrid")

# %% [markdown]
# ### Electric Vehicle Registration Data
#
# *Import and read data table*

# %%
vehicle_reg = pd.read_csv('Vehicle__Snowmobile__and_Boat_Registrations.csv')

# %%
vehicle_reg.head()
# Out:
#   Record Type                VIN Registration Class             City State  \
# 0        VEH   8995                             PAS  BUFFALO            NY
# 1        VEH   607SR2131A                       PAS  N SYRACUSE         NY
# 2        VEH   537LS7D46CT083476                PAS  NEWFANE            NY
# 3        VEH   53TBH2MC1BE900166                PAS  ROCKVILLE CTR      NY
# 4        VEH   53G1B4A47DB000347                PAS  BROOKLYN           NY
#
#      Zip        County  Model Year   Make Body Type Fuel Type  Unladen Weight  \
# 0  14207  ERIE                1913  DE/EL      2DSD  ELECTRIC            1100
# 1  13212  ONONDAGA            1977  CITI       2DSD  ELECTRIC            2590
# 2  14108  NIAGARA             2012  AZURE      SUBN  ELECTRIC            4005
# 3  11570  NASSAU              2011  THINK      2DSD  ELECTRIC            2348
# 4  11223  KINGS               2013  CODA       4DSD  ELECTRIC            3682
#
#    Maximum Gross Weight  Passengers Reg Valid Date Reg Expiration Date  Color  \
# 0                   NaN         NaN     05/31/2018          07/01/2020  MR
# 1                   NaN         NaN     11/21/2017          11/20/2019  RD
# 2                   NaN         NaN     05/16/2017          05/17/2019  WH
# 3                   NaN         NaN     04/18/2018          05/06/2020  RD
# 4                   NaN         NaN     08/08/2018          08/07/2020  BK
#
#   Scofflaw Indicator Suspension Indicator Revocation Indicator
# 0                  N                    N                    N
# 1                  N                    N                    N
# 2                  N                    N                    N
# 3                  N                    N                    N
# 4                  N                    N                    N

# %% [markdown]
# *Create a new table with only the relevant information to my study*

# %%
veh = vehicle_reg[['City','State','Zip','County']]
veh[:5]
# Out:
#               City State    Zip        County
# 0  BUFFALO            NY  14207  ERIE
# 1  N SYRACUSE         NY  13212  ONONDAGA
# 2  NEWFANE            NY  14108  NIAGARA
# 3  ROCKVILLE CTR      NY  11570  NASSAU
# 4  BROOKLYN           NY  11223  KINGS

# %% [markdown]
# *There are 9222 registered electric vehicles in NYS*

# %%
len(veh)
# Out:
# 9222

# %% [markdown]
# *Create a data series showing the number of electric vehicles per zip code in New York State*

# %%
veh['Number of Vehicles'] = ''
reg_car = veh.groupby(['Zip'])
count_car = reg_car.agg({'Number of Vehicles':'count'}).sort_values(['Number of Vehicles','Zip'], ascending=[False, True])
count_car[:5]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        Number of Vehicles
# Zip
# 10583                 200
# 11746                 114
# 11791                 109
# 10580                 103
# 11743                 101

# %%
ax = sns.countplot(x = "Zip", data = veh)
ax.set_xticklabels(ax.get_xticklabels(), 
                   rotation = 40, 
                   ha='right')
ax.figure.set_size_inches(12,4)
ax.axes.set_title("Electric Vehicles Registered by Zip Code in NYS",fontsize=18)
ax.set_xlabel("Zip Code",fontsize=12)
ax.set_ylabel("Number of Vehicles",fontsize=12)
#ax_seg = plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0.)
plt.tight_layout() 
plt.show()
#The best way to display this would be in GIS

# %%
vehicle_reg_zip = vehicle_reg.groupby(['Zip'])
vrzip = vehicle_reg_zip.size().sort_values(ascending = False)

# %%
vrzip = vrzip[:25]
vrzip
# Out:
# Zip
# 10583    200
# 11746    114
# 11791    109
# 10580    103
# 11743    101
# 11050     87
# 10538     81
# 10013     77
# 14850     75
# 10514     73
# 11030     72
# 11576     72
# 14534     67
# 10504     67
# 10011     65
# 10023     60
# 11797     58
# 11747     55
# 11545     54
# 10014     53
# 11733     52
# 10528     51
# 11568     50
# 11201     49
# 10956     48
# dtype: int64

# %% [markdown]
# ## Charging Hubs in New York State
#
# *Import and read data*

# %%
charge_hub = pd.read_csv('Electric_Vehicle_Charging_Stations_in_New_York.csv')
charge_hub.head()
# Out:
#   Fuel Type Code                                       Station Name  \
# 0           ELEC  Hudson Valley Community College - TEC-SMART Bu...
# 1           ELEC                                     EDISONPARKFAST
# 2           ELEC                                        CARCHARGING
# 3           ELEC                                        CARCHARGING
# 4           ELEC                                     EDISONPARKFAST
#
#   Street Address                            Intersection Directions      City  \
# 0  345 Hermes Rd                                                NaN     Malta
# 1    451 9th Ave   LOC #250 #2 LOT#250; ChargePoint America Program  New York
# 2  350 W 50th St  ICON MERCURY; Icon parking see attendant for a...  New York
# 3  310 W 39th St  ICON 310 W 39TH; Icon Parking systems see vale...  New York
# 4   50 W 44th St  LOC #100 LEVEL3; Located in basement level of ...  New York
#
#   State    ZIP  Plus4 Station Phone Status Code            ...              \
# 0    NY  12020    NaN  518-629-7075           E            ...
# 1    NY  10018    NaN  888-758-4389           E            ...
# 2    NY  10019    NaN  888-758-4389           E            ...
# 3    NY  10018    NaN  888-758-4389           E            ...
# 4    NY  10036    NaN  888-758-4389           E            ...
#
#     Latitude  Longitude Date Last Confirmed     ID               Updated At  \
# 0  42.971670 -73.774182          06/02/2017  36532  2018-02-06 21:00:03 UTC
# 1  40.754512 -73.995938          10/28/2018  36945  2018-10-28 09:03:02 UTC
# 2  40.763245 -73.988648          10/28/2018  37169  2018-10-28 09:03:02 UTC
# 3  40.755440 -73.992027          10/28/2018  38530  2018-10-28 09:03:02 UTC
# 4  40.755546 -73.982307          10/28/2018  38981  2018-10-28 09:03:02 UTC
#
#    Owner Type Code  Federal Agency ID  Federal Agency Name   Open Date  \
# 0               SG                NaN                  NaN  10/15/2010
# 1              NaN                NaN                  NaN         NaN
# 2              NaN                NaN                  NaN         NaN
# 3              NaN                NaN                  NaN         NaN
# 4              NaN                NaN                  NaN         NaN
#
#                     Location
# 0     (42.97167, -73.774182)
# 1    (40.754512, -73.995938)
# 2  (40.7632446, -73.9886475)
# 3  (40.7554398, -73.9920273)
# 4    (40.755546, -73.982307)
#
# [5 rows x 32 columns]

# %% [markdown]
# *Create a new table with only the relevant information to my study*

# %%
hub = charge_hub[['City','ZIP','Latitude','Longitude',]]
hub[:4]
# Out:
#        City    ZIP   Latitude  Longitude
# 0     Malta  12020  42.971670 -73.774182
# 1  New York  10018  40.754512 -73.995938
# 2  New York  10019  40.763245 -73.988648
# 3  New York  10018  40.755440 -73.992027

# %% [markdown]
# *There are 1030 charging ports in New York State*

# %%
len(hub)
# Out:
# 1030

# %% [markdown]
# *Map of Charging Hubs in New York State*

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(hub['Longitude'], hub['Latitude'],'b.',alpha=0.5)

# %% [markdown]
# *Create a data series showing the number of charging hugs per zip code in New York State*

# %%
hub['Number of Charge Hubs'] = ''
ch_hub = hub.groupby(['ZIP'])
count_hub = ch_hub.agg({'Number of Charge Hubs':'count'}).sort_values(['Number of Charge Hubs','ZIP'], ascending=[False, True])
count_hub[:5]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        Number of Charge Hubs
# ZIP
# 10019                     34
# 10016                     22
# 12401                     21
# 10021                     17
# 10022                     17

# %%
charge_hub_zip = charge_hub.groupby(['ZIP'])
chzip = charge_hub_zip.size().sort_values(ascending = False)

# %%
chzip = chzip[:25]
chzip
# Out:
# ZIP
# 10019    34
# 10016    22
# 12401    21
# 10022    17
# 10021    17
# 10023    16
# 14850    16
# 10065    15
# 12866    15
# 10028    14
# 10011    14
# 10024    13
# 11201    12
# 10025    12
# 10003    12
# 10036    11
# 10014     9
# 14221     9
# 10013     9
# 10075     8
# 11790     8
# 10001     8
# 11901     7
# 12205     7
# 11215     7
# dtype: int64

# %% [markdown]
# *Combine count_car and count_hub dataframes using concat, name the resulting table "complete"*

# %%
frames = [count_car, count_hub]
complete = pd.concat(frames, sort=True)
complete
# Out:
#        Number of Charge Hubs  Number of Vehicles
# 10583                    NaN               200.0
# 11746                    NaN               114.0
# 11791                    NaN               109.0
# 10580                    NaN               103.0
# 11743                    NaN               101.0
# 11050                    NaN                87.0
# 10538                    NaN                81.0
# 10013                    NaN                77.0
# 14850                    NaN                75.0
# 10514                    NaN                73.0
# 11030                    NaN                72.0
# 11576                    NaN                72.0
# 10504                    NaN                67.0
# 14534                    NaN                67.0
# 10011                    NaN                65.0
# 10023                    NaN                60.0
# 11797                    NaN                58.0
# 11747                    NaN                55.0
# 11545                    NaN                54.0
# 10014                    NaN                53.0
# 11733                    NaN                52.0
# 10528                    NaN                51.0
# 11568                    NaN                50.0
# 11201                    NaN                49.0
# 10128                    NaN                48.0
# 10804                    NaN                48.0
# 10956                    NaN                48.0
# 10024                    NaN                47.0
# 11768                    NaN                47.0
# 11040                    NaN                46.0
# ...                      ...                 ...
# 14216                    1.0                 NaN
# 14222                    1.0                 NaN
# 14414                    1.0                 NaN
# 14428                    1.0                 NaN
# 14445                    1.0                 NaN
# 14454                    1.0                 NaN
# 14485                    1.0                 NaN
# 14487                    1.0                 NaN
# 14526                    1.0                 NaN
# 14527                    1.0                 NaN
# 14534                    1.0                 NaN
# 14551                    1.0                 NaN
# 14569                    1.0                 NaN
# 14605                    1.0                 NaN
# 14607                    1.0                 NaN
# 14612                    1.0                 NaN
# 14615                    1.0                 NaN
# 14624                    1.0                 NaN
# 14626                    1.0                 NaN
# 14627                    1.0                 NaN
# 14642                    1.0                 NaN
# 14702                    1.0                 NaN
# 14731                    1.0                 NaN
# 14760                    1.0                 NaN
# 14817                    1.0                 NaN
# 14818                    1.0                 NaN
# 14837                    1.0                 NaN
# 14853                    1.0                 NaN
# 14870                    1.0                 NaN
# 14881                    1.0                 NaN
#
# [1420 rows x 2 columns]

# %%
#attempting to use replace to get rid of NaN
complete.replace('NaN',0)
# Out:
#        Number of Charge Hubs  Number of Vehicles
# 10583                    NaN               200.0
# 11746                    NaN               114.0
# 11791                    NaN               109.0
# 10580                    NaN               103.0
# 11743                    NaN               101.0
# 11050                    NaN                87.0
# 10538                    NaN                81.0
# 10013                    NaN                77.0
# 14850                    NaN                75.0
# 10514                    NaN                73.0
# 11030                    NaN                72.0
# 11576                    NaN                72.0
# 10504                    NaN                67.0
# 14534                    NaN                67.0
# 10011                    NaN                65.0
# 10023                    NaN                60.0
# 11797                    NaN                58.0
# 11747                    NaN                55.0
# 11545                    NaN                54.0
# 10014                    NaN                53.0
# 11733                    NaN                52.0
# 10528                    NaN                51.0
# 11568                    NaN                50.0
# 11201                    NaN                49.0
# 10128                    NaN                48.0
# 10804                    NaN                48.0
# 10956                    NaN                48.0
# 10024                    NaN                47.0
# 11768                    NaN                47.0
# 11040                    NaN                46.0
# ...                      ...                 ...
# 14216                    1.0                 NaN
# 14222                    1.0                 NaN
# 14414                    1.0                 NaN
# 14428                    1.0                 NaN
# 14445                    1.0                 NaN
# 14454                    1.0                 NaN
# 14485                    1.0                 NaN
# 14487                    1.0                 NaN
# 14526                    1.0                 NaN
# 14527                    1.0                 NaN
# 14534                    1.0                 NaN
# 14551                    1.0                 NaN
# 14569                    1.0                 NaN
# 14605                    1.0                 NaN
# 14607                    1.0                 NaN
# 14612                    1.0                 NaN
# 14615                    1.0                 NaN
# 14624                    1.0                 NaN
# 14626                    1.0                 NaN
# 14627                    1.0                 NaN
# 14642                    1.0                 NaN
# 14702                    1.0                 NaN
# 14731                    1.0                 NaN
# 14760                    1.0                 NaN
# 14817                    1.0                 NaN
# 14818                    1.0                 NaN
# 14837                    1.0                 NaN
# 14853                    1.0                 NaN
# 14870                    1.0                 NaN
# 14881                    1.0                 NaN
#
# [1420 rows x 2 columns]

# %%
#attempt #2: use fillna() to replace NaN in dataframe with 0
total = complete['Number of Charge Hubs'].fillna(value=0, inplace=True)
total
#The kernel runs, but there is no visible output.

# %%
#YES! finally got it :)  
#This code kills two birds with one stone, since it also converts to intergers
complete = complete.fillna(0).astype(int)
complete
# Out:
#        Number of Charge Hubs  Number of Vehicles
# 10583                      0                 200
# 11746                      0                 114
# 11791                      0                 109
# 10580                      0                 103
# 11743                      0                 101
# 11050                      0                  87
# 10538                      0                  81
# 10013                      0                  77
# 14850                      0                  75
# 10514                      0                  73
# 11030                      0                  72
# 11576                      0                  72
# 10504                      0                  67
# 14534                      0                  67
# 10011                      0                  65
# 10023                      0                  60
# 11797                      0                  58
# 11747                      0                  55
# 11545                      0                  54
# 10014                      0                  53
# 11733                      0                  52
# 10528                      0                  51
# 11568                      0                  50
# 11201                      0                  49
# 10128                      0                  48
# 10804                      0                  48
# 10956                      0                  48
# 10024                      0                  47
# 11768                      0                  47
# 11040                      0                  46
# ...                      ...                 ...
# 14216                      1                   0
# 14222                      1                   0
# 14414                      1                   0
# 14428                      1                   0
# 14445                      1                   0
# 14454                      1                   0
# 14485                      1                   0
# 14487                      1                   0
# 14526                      1                   0
# 14527                      1                   0
# 14534                      1                   0
# 14551                      1                   0
# 14569                      1                   0
# 14605                      1                   0
# 14607                      1                   0
# 14612                      1                   0
# 14615                      1                   0
# 14624                      1                   0
# 14626                      1                   0
# 14627                      1                   0
# 14642                      1                   0
# 14702                      1                   0
# 14731                      1                   0
# 14760                      1                   0
# 14817                      1                   0
# 14818                      1                   0
# 14837                      1                   0
# 14853                      1                   0
# 14870                      1                   0
# 14881                      1                   0
#
# [1420 rows x 2 columns]

# %%
complete1 = DataFrame(complete, columns = ['Zip Code', '# of Charge Hubs','# of EV'])
complete1[:5]
# Out:
#        Zip Code  # of Charge Hubs  # of EV
# 10583       NaN               NaN      NaN
# 11746       NaN               NaN      NaN
# 11791       NaN               NaN      NaN
# 10580       NaN               NaN      NaN
# 11743       NaN               NaN      NaN

# %% [markdown]
# **Next Steps**
# 1. Combine count_car and count_hub data series into one data frame to compare the number of cars in each zip code and the number of charging hubs.  This will help give an idea of demand for hubs. (*Completed*)
# 3. Create a new column in charge_hub for County.  Match County to zip code in charge_hub, try creating a new dataframe called County from vehicle_reg with only zip and county columns, and work using that.
# 2. Map number of cars per zip code and the locations of charging hubs using geocoding and ArcGIS

# %% [markdown]
# ## Getting "County" column in charging hubs dataframe

# %%
county = vehicle_reg[['Zip','County']]
county[:5]
# Out:
#      Zip        County
# 0  14207  ERIE
# 1  13212  ONONDAGA
# 2  14108  NIAGARA
# 3  11570  NASSAU
# 4  11223  KINGS

# %%
#This is not what I was going for, but this might be helpful. Compare charging hubs 
#and electric vehicles by county rather than zip code
county['Number of Vehicles'] = ''
reg_county = county.groupby(['County'])
count_county = reg_county.agg({'Number of Vehicles':'count'}).sort_values(['Number of Vehicles','County'], ascending=[False, True])
count_county
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Number of Vehicles
# County
# WESTCHESTER                 1577
# NASSAU                      1486
# SUFFOLK                     1196
# NEW YORK                     875
# QUEENS                       456
# MONROE                       423
# KINGS                        422
# ERIE                         283
# ROCKLAND                     251
# ALBANY                       226
# DUTCHESS                     202
# ULSTER                       156
# RICHMOND                     152
# ONONDAGA                     147
# SARATOGA                     142
# ORANGE                       140
# SCHENECTADY                  115
# TOMPKINS                     113
# RENSSELAER                    84
# BRONX                         77
# ONTARIO                       53
# PUTNAM                        53
# NIAGARA                       52
# BROOME                        45
# COLUMBIA                      31
# ONEIDA                        31
# OUT-OF-STATE                  30
# WARREN                        26
# STEUBEN                       24
# CHEMUNG                       21
# ...                          ...
# SULLIVAN                      21
# ESSEX                         20
# LIVINGSTON                    17
# CHAUTAUQUA                    16
# MADISON                       16
# WASHINGTON                    15
# WAYNE                         15
# CAYUGA                        13
# OTSEGO                        13
# OSWEGO                        12
# JEFFERSON                     11
# TIOGA                         11
# DELAWARE                       9
# FULTON                         9
# MONTGOMERY                     9
# ST LAWRENCE                    9
# SCHOHARIE                      8
# SCHUYLER                       8
# CATTARAUGUS                    7
# CHENANGO                       7
# CORTLAND                       7
# FRANKLIN                       6
# ORLEANS                        6
# SENECA                         6
# GENESEE                        5
# HERKIMER                       5
# WYOMING                        3
# YATES                          3
# ALLEGANY                       2
# HAMILTON                       2
#
# [62 rows x 1 columns]

# %%
#ax = sns.countplot(x = 'County', data = count_county)
#ax.set_xticklabels(ax.get_xticklabels(), 
                   #rotation = 40, 
                   #ha='right')
#ax.figure.set_size_inches(12,4)
#ax.axes.set_title('Electric Vehicles Registered by County in NYS',fontsize=18)
#ax.set_xlabel('County',fontsize=12)
#ax.set_ylabel('Number of Vehicles',fontsize=12)
#ax_seg = plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0.)
#plt.tight_layout() 
#plt.show()

# %% [markdown]
# ## Counties to Regions

# %% [markdown]
# Create a table in Excel. Split NYS into 9 regions according to NYS DEC. Upload table to notebook, attach to county_county dataframe.  Create a new dataframe that counts the EV registrations in each region.

# %%
from pandas import DataFrame
region = pd.read_excel(r'/Users/ceciliapershyn/CIS_512_Term_Project/county_to_region.xlsx')
region = DataFrame(region, columns=['Region_Code','Region','County'])
region[:5]
# Out:
#    Region_Code         Region    County
# 0            1    Long Island    Nassau
# 1            1    Long Island   Suffolk
# 2            2  New York City     Kings
# 3            2  New York City     Bronx
# 4            2  New York City  New York

# %% [markdown]
# Convert County column to uppercase so its format will match the County columns in other tables when I do the join.

# %%
region['County'] = region['County'].str.upper()
region[:5]
# Out:
#    Region_Code         Region    County
# 0            1    Long Island    NASSAU
# 1            1    Long Island   SUFFOLK
# 2            2  New York City     KINGS
# 3            2  New York City     BRONX
# 4            2  New York City  NEW YORK

# %%
#attempt 1: concat
frames2 = [county, region]
count_reg = pd.concat(frames2, axis=1, join='inner', sort=True)
count_reg
# Out:
#       Zip        County Number of Vehicles  Region_Code                Region  \
# 0   14207  ERIE                                       1           Long Island
# 1   13212  ONONDAGA                                   1           Long Island
# 2   14108  NIAGARA                                    2         New York City
# 3   11570  NASSAU                                     2         New York City
# 4   11223  KINGS                                      2         New York City
# 5   11702  SUFFOLK                                    2         New York City
# 6   12222  ALBANY                                     2         New York City
# 7   12222  ALBANY                                     3   Lower Hudson Valley
# 8   11223  KINGS                                      3   Lower Hudson Valley
# 9   11743  SUFFOLK                                    3   Lower Hudson Valley
# 10  11769  SUFFOLK                                    3   Lower Hudson Valley
# 11  10520  WESTCHESTER                                3   Lower Hudson Valley
# 12  11762  NASSAU                                     3   Lower Hudson Valley
# 13  11050  NASSAU                                     3   Lower Hudson Valley
# 14  10305  RICHMOND                                   4        Capital Region
# 15  10543  WESTCHESTER                                4        Capital Region
# 16  11040  NASSAU                                     4        Capital Region
# 17  10583  WESTCHESTER                                4        Capital Region
# 18  11020  NASSAU                                     4        Capital Region
# 19  11362  QUEENS                                     4        Capital Region
# 20  12533  DUTCHESS                                   4        Capital Region
# 21  10710  WESTCHESTER                                4        Capital Region
# 22  12561  ULSTER                                     4        Capital Region
# 23  10580  WESTCHESTER                                5   Eastern Adirondacks
# 24  10522  WESTCHESTER                                5   Eastern Adirondacks
# 25  11705  SUFFOLK                                    5   Eastern Adirondacks
# 26  11757  SUFFOLK                                    5   Eastern Adirondacks
# 27  11746  SUFFOLK                                    5   Eastern Adirondacks
# 28  12590  DUTCHESS                                   5   Eastern Adirondacks
# 29  11746  SUFFOLK                                    5   Eastern Adirondacks
# ..    ...           ...                ...          ...                   ...
# 32  11753  NASSAU                                     6   Western Adirondacks
# 33  11373  QUEENS                                     6   Western Adirondacks
# 34  10940  ORANGE                                     6   Western Adirondacks
# 35  11101  QUEENS                                     6   Western Adirondacks
# 36  11743  SUFFOLK                                    7      Central New York
# 37  11040  NASSAU                                     7      Central New York
# 38  10036  NEW YORK                                   7      Central New York
# 39  10473  BRONX                                      7      Central New York
# 40  11222  KINGS                                      7      Central New York
# 41  12845  WARREN                                     7      Central New York
# 42  11238  KINGS                                      7      Central New York
# 43  11554  NASSAU                                     7      Central New York
# 44  10952  ROCKLAND                                   7      Central New York
# 45  12148  SARATOGA                                   8  Western Finger Lakes
# 46  10583  WESTCHESTER                                8  Western Finger Lakes
# 47  11357  QUEENS                                     8  Western Finger Lakes
# 48  11354  QUEENS                                     8  Western Finger Lakes
# 49  11238  KINGS                                      8  Western Finger Lakes
# 50  14216  ERIE                                       8  Western Finger Lakes
# 51  11743  SUFFOLK                                    8  Western Finger Lakes
# 52  11767  SUFFOLK                                    8  Western Finger Lakes
# 53  11791  NASSAU                                     8  Western Finger Lakes
# 54  11598  NASSAU                                     8  Western Finger Lakes
# 55  11109  QUEENS                                     8  Western Finger Lakes
# 56  10990  ORANGE                                     9      Western New York
# 57  11507  NASSAU                                     9      Western New York
# 58  10012  NEW YORK                                   9      Western New York
# 59  10977  ROCKLAND                                   9      Western New York
# 60  11105  QUEENS                                     9      Western New York
# 61  11937  SUFFOLK                                    9      Western New York
#
#           County
# 0         NASSAU
# 1        SUFFOLK
# 2          KINGS
# 3          BRONX
# 4       NEW YORK
# 5         QUEENS
# 6       RICHMOND
# 7       DUTCHESS
# 8         ORANGE
# 9         PUTNAM
# 10      ROCKLAND
# 11      SULLIVAN
# 12        ULSTER
# 13   WESTCHESTER
# 14        ALBANY
# 15      COLUMBIA
# 16      DELAWARE
# 17        GREENE
# 18    MONTGOMERY
# 19        OTSEGO
# 20    RENSSELAER
# 21   SCHENECTADY
# 22     SCHOHARIE
# 23       CLINTON
# 24         ESSEX
# 25      FRANKLIN
# 26        FULTON
# 27      HAMILTON
# 28      SARATOGA
# 29        WARREN
# ..           ...
# 32     JEFFERSON
# 33         LEWIS
# 34        ONEIDA
# 35  ST. LAWRENCE
# 36        BROOME
# 37        CAYUGA
# 38      CHENANGO
# 39      CORTLAND
# 40       MADISON
# 41      ONONDAGA
# 42        OSWEGO
# 43          TIOA
# 44      TOMPKINS
# 45       CHEMUNG
# 46       GENESEE
# 47    LIVINGSTON
# 48        MONROE
# 49       ONTARIO
# 50       ORLEANS
# 51      SCHUYLER
# 52        SENECA
# 53       STEUBEN
# 54         WAYNE
# 55         YATES
# 56      ALLEGANY
# 57    CHAUTAUQUA
# 58   CATTARAUGUS
# 59          ERIE
# 60       NIAGARA
# 61       WYOMING
#
# [62 rows x 6 columns]

# %%
#attempt 2: join veh and region
veh_count_reg = pd.merge_ordered(veh, region, fill_method='ffill', left_by = 'County')
veh_count_reg[:25]
# Out:
#                City State    Zip        County Number of Vehicles  \
# 0   BUFFALO            NY  14207  ERIE
# 1   BUFFALO            NY  14216  ERIE
# 2   WEST FALLS         NY  14170  ERIE
# 3   BUFFALO            NY  14224  ERIE
# 4   CLARENCE           NY  14031  ERIE
# 5   DEPEW              NY  14043  ERIE
# 6   WILLIAMSVILLE      NY  14221  ERIE
# 7   CLARENCE           NY  14031  ERIE
# 8   CLARENCE           NY  14031  ERIE
# 9   ELMA               NY  14059  ERIE
# 10  AMHERST            NY  14228  ERIE
# 11  WILLIAMSVILLE      NY  14221  ERIE
# 12  EAST AMHERST       NY  14051  ERIE
# 13  AMHERST            NY  14226  ERIE
# 14  CLARENCE CNTR      NY  14032  ERIE
# 15  BUFFALO            NY  14221  ERIE
# 16  BUFFALO            NY  14222  ERIE
# 17  CHEEKTOWAGA        NY  14225  ERIE
# 18  LANCASTER          NY  14086  ERIE
# 19  BUFFALO            NY  14220  ERIE
# 20  BUFFALO            NY  14221  ERIE
# 21  EAST AURORA        NY  14052  ERIE
# 22  WILLIAMSVILLE      NY  14221  ERIE
# 23  WILLIAMSVILLE      NY  14221  ERIE
# 24  HAMBURG            NY  14075  ERIE
#
#     Region_Code  Region
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN
# 5           NaN     NaN
# 6           NaN     NaN
# 7           NaN     NaN
# 8           NaN     NaN
# 9           NaN     NaN
# 10          NaN     NaN
# 11          NaN     NaN
# 12          NaN     NaN
# 13          NaN     NaN
# 14          NaN     NaN
# 15          NaN     NaN
# 16          NaN     NaN
# 17          NaN     NaN
# 18          NaN     NaN
# 19          NaN     NaN
# 20          NaN     NaN
# 21          NaN     NaN
# 22          NaN     NaN
# 23          NaN     NaN
# 24          NaN     NaN

# %%
veh_count_county = complete.merge(county, how='inner', left_on = 'Zip', right_on = 'Zip')
veh_count_county[:25]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-e23111d964e5> in <module>()
# ----> 1 veh_count_county = complete.merge(county, how='inner', left_on = 'Zip', right_on = 'Zip')
#       2 veh_count_county[:25]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6377                      right_on=right_on, left_index=left_index,
#    6378                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6379                      copy=copy, indicator=indicator, validate=validate)
#    6380
#    6381     def round(self, decimals=0, *args, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     548         (self.left_join_keys,
#     549          self.right_join_keys,
# --> 550          self.join_names) = self._get_merge_keys()
#     551
#     552         # validate the merge keys dtypes. We may need to coerce
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     868                     if lk is not None:
#     869                         left_keys.append(left._get_label_or_level_values(
# --> 870                             lk, stacklevel=stacklevel))
#     871                         join_names.append(lk)
#     872                     else:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1377             values = self.axes[axis].get_level_values(key)._values
#    1378         else:
# -> 1379             raise KeyError(key)
#    1380
#    1381         # Check for duplicates
#
# KeyError: 'Zip'
